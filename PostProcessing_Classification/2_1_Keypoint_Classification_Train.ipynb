# %% [markdown]
# ## 0. Load Library

# %%
import easydict

import json
import os
import pickle
import ast

import pandas as pd
import numpy as np

from varname import nameof

import matplotlib.pyplot as plt
import itertools
from yellowbrick.classifier import ClassificationReport
from yellowbrick.datasets import load_occupancy

# %%
from sklearn.model_selection import train_test_split

from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression

from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import MaxAbsScaler
from sklearn.model_selection import KFold
from sklearn.model_selection import GridSearchCV

from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %% [markdown]
# ## 1. Variable Declaration

# %%
args = easydict.EasyDict({
        "title" : "VGG_Retina_ML_Grid_DCGAN1",
        "device" : "cuda",
        "root" : "data",
        "dataset_path" : "C:\\Users\\Bang\\JupyterProjects\\ComputerVision\\Skeleton\\dataset\\",
        "json_path" : "C:\\Users\\Bang\\JupyterProjects\\ComputerVision\\Skeleton\\dataset\\json\\",
        "split_list_path" : "C:\\Users\\Bang\\JupyterProjects\\ComputerVision\\Skeleton\\dataset\\split_list\\",
        "error_list_path" : "C:\\Users\\Bang\\JupyterProjects\\ComputerVision\\Skeleton\dataset\\error_list\\",
        "error_list_txt_path" : "C:\\Users\\Bang\\JupyterProjects\\ComputerVision\\Skeleton\dataset\\error_list\\error_list.txt",
        "saved_model_path" : "C:\\Users\\Bang\\JupyterProjects\\ComputerVision\\Skeleton\\saved_model\\",
        "keypoints_num" : 17,
        "keypoints_dimension" : ["x", "y"],
        "scaler": {"MinMaxScaler":MinMaxScaler(), "StandardScaler":StandardScaler(), "RobustScaler":RobustScaler(), "MaxAbsScaler":MaxAbsScaler()},
        "scaler_default": RobustScaler(),
        "y_list": {"neck":"neck", "trunk":"trunk", "upperarm":"upperarm", "lowerarm":"lowerarm", "legs":"legs", "json_trunk_twist":"json_trunk_twist"},
        "y_default":"neck",
        "classifier":{"KC":KNeighborsClassifier(n_neighbors = 5), "DTC":DecisionTreeClassifier(random_state=32), "RFC":RandomForestClassifier(random_state=32), "SVC":svm.SVC()},
        "classifier_default":KNeighborsClassifier(n_neighbors = 5),
        "best_classifier_name":"KC",
        "knn_neighbors_list" : range(1,51),
        "accuracy_log" : [],
        "accuracy_logs" : {},
        "con_mat_logs" : {},
        "classification_report_logs":{},
        "json_data" : dict(),
        "use_data" : "Retina_Some_binary_DCGAN", # Retina_Some_binary # Retina_Some_binary_GAN284 # Retina_Some_binary_GAN852 # Retina_student
        "batch_size" : 32, # !!!
        "num_workers" : 2,
        "epochs" : 100, # !!!
        #ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
        # "lr" : 7.5e-5, # !!!
        "lr" : 5e-5, # 1e-6, 5e-3 # 1e-6, 5e-5 !!!
        #ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ
        "logs" : "logs",
        "checkpoints" : "checkpoints",
        "transform_dir" : "transform_infor",
        "resume" : False,
        "train_ratio" : 0.8,
        "val_ratio" : 0.2,
        "test_ratio" : 1.0,
        "output_dim" : 2,
        "drop_rate": 0.5
    })

# %% [markdown]
# ## 2. Data Preprocessing

# %% [markdown]
# ### 1) JSON list

# %%
json_list = os.listdir(args.json_path)

json_list
# Out:
# ['F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0011.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0012.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0013.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0014.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0015.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0016.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0017.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0018.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0019.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0020.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0021.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0022.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0023.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0024.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0025.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0026.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0027.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0028.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0029.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0030.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0031.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0032.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0033.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0034.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0035.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0036.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0037.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0038.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0039.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0040.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0041.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0042.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0043.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0044.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0045.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0046.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0047.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0048.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0049.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0050.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0051.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0052.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0053.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0054.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0055.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0056.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0057.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0058.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0059.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0060.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0061.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0062.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0063.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0064.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0065.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0066.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0067.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0068.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0069.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0070.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0071.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0072.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0073.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0074.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0075.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0076.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0077.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0078.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0079.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0080.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0081.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0082.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0083.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0084.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0085.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0086.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0087.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0088.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0089.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0090.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0091.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0092.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0093.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0094.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0095.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0096.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0097.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0098.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0099.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0100.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0101.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0102.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0103.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0104.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0105.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0106.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0107.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0108.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0109.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0110.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0111.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0112.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0113.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0114.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0115.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0116.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0117.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0118.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0119.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0120.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0121.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0122.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0123.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0124.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0125.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0126.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0127.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0128.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0129.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0130.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0131.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0132.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0133.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0134.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0135.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0136.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0137.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0138.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0139.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0140.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0141.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0142.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0143.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0144.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0145.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0146.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0147.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0148.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0149.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0150.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0151.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0152.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0153.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0154.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0155.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0156.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0157.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0158.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0159.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0160.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0161.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0162.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0163.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0164.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0165.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0166.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0167.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0168.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0169.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0170.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0171.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0172.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0173.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0174.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0175.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0176.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0177.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0178.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0179.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0180.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0181.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0182.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0183.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0184.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0185.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0186.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0187.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0188.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0189.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0190.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0191.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0192.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0193.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0194.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0195.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0196.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0197.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0198.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0199.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0200.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0201.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0202.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0203.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0204.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0205.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0206.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0207.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0208.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0209.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0210.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0211.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0212.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0213.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0214.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0215.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0216.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0217.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0218.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0219.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0220.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0221.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0222.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0223.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0224.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0225.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0226.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0227.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0228.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0229.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0230.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0231.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0232.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0233.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0234.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0235.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0236.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0237.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0238.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0241.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0242.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0243.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0244.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0245.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0246.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0247.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0248.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0249.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0250.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0251.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0252.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0253.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0254.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0255.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0256.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0257.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0258.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0259.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0261.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0262.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0263.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0264.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0266.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0267.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0268.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0269.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0270.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0271.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0272.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0273.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0274.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0275.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0276.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0277.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0278.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0279.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0358.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0359.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0360.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0361.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0362.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0363.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0364.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0365.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0366.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0367.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0368.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0369.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0370.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0371.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0372.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0373.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0374.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0375.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0376.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0377.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0378.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0379.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0380.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0381.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0382.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0383.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0384.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0385.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0386.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0389.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0390.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0391.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0392.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0394.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0395.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0396.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0397.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0398.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0399.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0400.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0401.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0402.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0403.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0404.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0405.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0406.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0407.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0408.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0409.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0410.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0411.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0412.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0413.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0414.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0415.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0416.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0417.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0418.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0419.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0420.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0421.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0422.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0423.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0424.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0425.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0426.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0427.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0428.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0429.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0430.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0431.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0432.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0433.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0434.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0435.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0436.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0437.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0438.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0439.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0440.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0441.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0442.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0443.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0444.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0445.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0446.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0447.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0448.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0449.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0450.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0451.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0452.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0453.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0454.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0455.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0456.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0457.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0458.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0459.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0460.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0461.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0462.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0463.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0464.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0465.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0466.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0467.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0468.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0469.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0470.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0471.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0472.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0473.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0474.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0475.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0476.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0477.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0478.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0479.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0480.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0481.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0482.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0483.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0484.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0485.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0486.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0487.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0488.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0489.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0490.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0491.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0492.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0493.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0494.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0495.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0496.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0497.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0498.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0499.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0500.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0501.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0502.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0503.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0504.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0505.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0506.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0507.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0508.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0509.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0510.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0511.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0512.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0513.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0514.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0515.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0516.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0517.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0518.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0519.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0520.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0521.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0522.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0523.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0524.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0525.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0526.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0527.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0528.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0529.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0530.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0531.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0532.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0533.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0534.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0535.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0536.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0537.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0538.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0539.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0540.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0541.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0542.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0543.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0544.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0545.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0546.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0547.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0548.json',
#  'F01_P001_A1_W001_D2022-08-23-10-12-00_0549.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0001.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0002.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0003.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0004.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0005.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0006.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0007.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0008.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0009.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0010.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0011.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0012.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0013.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0016.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0024.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0025.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0026.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0027.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0028.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0029.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0030.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0031.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0032.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0033.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0034.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0035.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0036.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0037.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0038.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0039.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0040.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0041.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0042.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0043.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0044.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0045.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0046.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0047.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0048.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0049.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0050.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0051.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0052.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0053.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0054.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0055.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0056.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0057.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0058.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0059.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0060.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0061.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0062.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0063.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0064.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0065.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0066.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0067.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0068.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0069.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0070.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0071.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0072.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0073.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0074.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0075.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0076.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0077.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0078.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0079.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0080.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0081.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0082.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0083.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0084.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0085.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0086.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0087.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0088.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0089.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0090.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0091.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0092.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0093.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0094.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0095.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0096.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0097.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0098.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0099.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0100.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0101.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0102.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0103.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0104.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0105.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0106.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0107.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0108.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0109.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0110.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0111.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0112.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0113.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0114.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0115.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0116.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0117.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0118.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0119.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0120.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0121.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0122.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0123.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0124.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0125.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0126.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0127.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0128.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0129.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0130.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0131.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0132.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0133.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0134.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0135.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0136.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0137.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0138.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0139.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0140.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0141.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0142.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0143.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0144.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0145.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0146.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0147.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0148.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0149.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0150.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0151.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0152.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0153.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0154.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0155.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0156.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0157.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0158.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0159.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0160.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0161.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0162.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0163.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0164.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0165.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0166.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0167.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0168.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0169.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0170.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0171.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0172.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0173.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0174.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0175.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0176.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0177.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0178.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0179.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0180.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0181.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0182.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0183.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0184.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0185.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0186.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0187.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0188.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0189.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0190.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0191.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0192.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0193.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0194.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0195.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0196.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0197.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0198.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0199.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0200.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0201.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0202.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0203.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0204.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0205.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0206.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0207.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0208.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0209.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0210.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0211.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0212.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0213.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0214.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0215.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0216.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0217.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0218.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0219.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0220.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0221.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0222.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0223.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0224.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0225.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0226.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0227.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0228.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0229.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0230.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0231.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0232.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0233.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0234.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0235.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0236.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0237.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0238.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0239.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0241.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0242.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0243.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0244.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0245.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0246.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0247.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0248.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0249.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0250.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0251.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0252.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0253.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0254.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0255.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0256.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0257.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0258.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0259.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0260.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0261.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0262.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0263.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0264.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0265.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0266.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0267.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0268.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0269.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0270.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0271.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0272.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0273.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0274.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0275.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0276.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0277.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0278.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0280.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0281.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0282.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0283.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0284.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0285.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0286.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0287.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0288.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0289.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0290.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0291.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0292.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0293.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0294.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0295.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0296.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0297.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0298.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0299.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0300.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0301.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0302.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0303.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0304.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0305.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0306.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0307.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0308.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0309.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0310.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0311.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0312.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0313.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0314.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0315.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0316.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0317.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0318.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0319.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0320.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0321.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0322.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0323.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0324.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0326.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0327.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0328.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0329.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0330.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0331.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0332.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0333.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0334.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0335.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0336.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0337.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0338.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0339.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0340.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0341.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0342.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0343.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0344.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0345.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0346.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0347.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0348.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0349.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0350.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0351.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0352.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0353.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0354.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0355.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0356.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0357.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0358.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0359.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0360.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0361.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0362.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0363.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0364.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0365.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0366.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0367.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0368.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0369.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0370.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0371.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0372.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0373.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0374.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0375.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0376.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0377.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0378.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0379.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0380.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0381.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0382.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0383.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0384.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0385.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0386.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0387.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0388.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0389.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0390.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0391.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0392.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0393.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0394.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0395.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0396.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0397.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0398.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0399.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0400.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0401.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0402.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0403.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0404.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0405.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0406.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0407.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0408.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0409.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0410.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0411.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0412.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0413.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0414.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0415.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0416.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0417.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0418.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0419.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0420.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0421.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0422.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0423.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0424.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0425.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0426.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0427.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0428.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0429.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0430.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0431.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0432.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0433.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0434.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0435.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0436.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0437.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0438.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0439.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0440.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0441.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0442.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0443.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0444.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0446.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0447.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0449.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0450.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0451.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0452.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0453.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0454.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0455.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0456.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0457.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0458.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0459.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0460.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0461.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0462.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0463.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0464.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0465.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0466.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0467.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0468.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0469.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0470.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0471.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0472.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0473.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0474.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0475.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0476.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0477.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0478.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0479.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0480.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0481.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0482.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0483.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0484.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0485.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0486.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0487.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0488.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0489.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0490.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0491.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0492.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0493.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0494.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0495.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0496.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0497.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0498.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0499.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0500.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0501.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0502.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0503.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0504.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0505.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0506.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0507.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0508.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0509.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0510.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0511.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0512.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0513.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0514.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0515.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0516.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0517.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0518.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0519.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0520.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0521.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0522.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0523.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0524.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0525.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0526.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0527.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0528.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0529.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0530.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0532.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0533.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0534.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0535.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0536.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0537.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0538.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0539.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0540.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0541.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0542.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0543.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0544.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0545.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0546.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0547.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0548.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0549.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0550.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0551.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0552.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0553.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0554.json',
#  'F01_P001_A1_W001_D2022-08-23-10-22-00_0555.json',
#  ...]

# %% [markdown]
# ### 2) JSON keys define

# %%
json_skeleton_keys = []
for i in range(1, args.keypoints_num+1):
    for j in args.keypoints_dimension:
        json_skeleton_keys.append(f"{j}{i}")
json_skeleton_keys
# Out:
# ['x1',
#  'y1',
#  'x2',
#  'y2',
#  'x3',
#  'y3',
#  'x4',
#  'y4',
#  'x5',
#  'y5',
#  'x6',
#  'y6',
#  'x7',
#  'y7',
#  'x8',
#  'y8',
#  'x9',
#  'y9',
#  'x10',
#  'y10',
#  'x11',
#  'y11',
#  'x12',
#  'y12',
#  'x13',
#  'y13',
#  'x14',
#  'y14',
#  'x15',
#  'y15',
#  'x16',
#  'y16',
#  'x17',
#  'y17']

# %%
json_bbox_keys = ["bbox_w", "bbox_h"]

# %% [markdown]
# ### 3) JSON DF(posture + skeleton + bbox) make

# %%
for i, json_file in enumerate(json_list):
    json_full_path = args.json_path+json_file
    with open(json_full_path, 'r') as json_open:
        json_contents = json.loads(json_open.read())
        
        json_posture = json_contents["annotations"][0]["posture"]
        json_posture_keys = list(json_posture.keys())
        json_posture_values = list(json_posture.values())
        json_trunk_twist_keys = ["json_trunk_twist"]
        json_trunk_twist_values = [json_contents["annotations"][0]['trunk_twist']]
        json_skeleton_keys = json_skeleton_keys
        json_skeleton_values = json_contents["skeleton"]
        json_path_keys = ["json_path"]
        json_path_values = [json_file]
        
        json_bbox_x1 = json_contents["annotations"][0]['bbox'][0]
        json_bbox_y1 = json_contents["annotations"][0]['bbox'][1]
        json_bbox_x2 = json_contents["annotations"][0]['bbox'][2]
        json_bbox_y2 = json_contents["annotations"][0]['bbox'][3]
        json_bbox_w = json_bbox_x2 - json_bbox_x1
        json_bbox_h = json_bbox_y2 - json_bbox_y1
        json_bbox_keys = json_bbox_keys
        json_bbox_values = [json_bbox_w, json_bbox_h]
        
        json_all_keys = json_posture_keys + json_trunk_twist_keys + json_bbox_keys + json_skeleton_keys + json_path_keys
        json_all_values = json_posture_values + json_trunk_twist_values + json_bbox_values + json_skeleton_values + json_path_values
        if i==0:
            json_df = pd.DataFrame([json_all_values], columns = json_all_keys, index=[json_file])
        else:
            json_df.loc[json_file] = json_all_values

# %% [markdown]
# ### 4) Visualization

# %%
json_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19955 entries, F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json to F05_P001_A3_W001_D2022-09-23-10-23-27_0618.json
# Data columns (total 43 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   neck              19955 non-null  object
#  1   trunk             19955 non-null  object
#  2   upperarm          19955 non-null  object
#  3   lowerarm          19955 non-null  object
#  4   legs              19955 non-null  object
#  5   json_trunk_twist  19955 non-null  object
#  6   bbox_w            19955 non-null  float64
#  7   bbox_h            19955 non-null  float64
#  8   x1                19955 non-null  int64
#  9   y1                19955 non-null  int64
#  10  x2                19955 non-null  int64
#  11  y2                19955 non-null  int64
#  12  x3                19955 non-null  int64
#  13  y3                19955 non-null  int64
#  14  x4                19955 non-null  int64
#  15  y4                19955 non-null  int64
#  16  x5                19955 non-null  int64
#  17  y5                19955 non-null  int64
#  18  x6                19955 non-null  int64
#  19  y6                19955 non-null  int64
#  20  x7                19955 non-null  int64
#  21  y7                19955 non-null  int64
#  22  x8                19955 non-null  int64
#  23  y8                19955 non-null  int64
#  24  x9                19955 non-null  int64
#  25  y9                19955 non-null  int64
#  26  x10               19955 non-null  int64
#  27  y10               19955 non-null  int64
#  28  x11               19955 non-null  int64
#  29  y11               19955 non-null  int64
#  30  x12               19955 non-null  int64
#  31  y12               19955 non-null  int64
#  32  x13               19955 non-null  int64
#  33  y13               19955 non-null  int64
#  34  x14               19955 non-null  int64
#  35  y14               19955 non-null  int64
#  36  x15               19955 non-null  int64
#  37  y15               19955 non-null  int64
#  38  x16               19955 non-null  int64
#  39  y16               19955 non-null  int64
#  40  x17               19955 non-null  int64
#  41  y17               19955 non-null  int64
#  42  json_path         19955 non-null  object
# dtypes: float64(2), int64(34), object(7)
# memory usage: 6.7+ MB

# %%
json_df.shape
# Out:
# (19955, 43)

# %%
json_df.head()
# Out:
#                                                 neck trunk upperarm lowerarm  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json    2     1        0        0
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json    2     1        0        0
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json    2     1        0        0
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json    1     0        0        1
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json    1     0        1        0
#
#                                                 legs json_trunk_twist  bbox_w  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json    4                1   434.4
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json    4                0   428.0
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json    4                0   398.4
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json    4                0   365.6
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json    1                0   457.6
#
#                                                  bbox_h  x1  y1  ...  y13  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json   712.8  89  56  ...   75
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json   742.4  87  41  ...   82
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json   901.6  84  51  ...  114
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json  1016.8  72  56  ...  141
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json  1098.4  83 -67  ...   16
#
#                                                  x14  y14  x15  y15  x16  y16  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json   53  104   55  127   55  142
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json   53  133   56  134   55  171
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json   54  165   53  166   50  211
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json   56  189   57  188   52  237
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json   46    4   70   14   31   19
#
#                                                  x17  y17  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json   57  168
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json   57  173
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json   51  209
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json   51  236
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json   43   25
#
#                                                                                        json_path
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json  F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json  F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json  F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json  F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json  F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json
#
# [5 rows x 43 columns]

# %%
# json_df

# %% [markdown]
# ### 5) Data Unification

# %% [markdown]
# #### (1) Unique Value Check

# %%
for i in json_posture_keys:
    print(f"====================={i}=====================")
    print("ㅡㅡㅡㅡㅡjson_df[i].unique()ㅡㅡㅡㅡㅡ")
    print(json_df[i].unique())
    print("ㅡㅡㅡㅡㅡtype(json_df[i].unique()ㅡㅡㅡㅡㅡ")
    print(type(json_df[i].unique()))
    print("ㅡㅡㅡㅡㅡjson_df['neck'].value_counts()ㅡㅡㅡㅡㅡ")
    print(json_df['neck'].value_counts())
    print("ㅡㅡㅡㅡㅡjson_df['neck'].value_counts(normalize=True)ㅡㅡㅡㅡㅡ")
    print(json_df['neck'].value_counts(normalize=True))
# Out:
# =====================neck=====================
# ㅡㅡㅡㅡㅡjson_df[i].unique()ㅡㅡㅡㅡㅡ
# ['2' 2 '1' 1 '0' 0 '']
# ㅡㅡㅡㅡㅡtype(json_df[i].unique()ㅡㅡㅡㅡㅡ
# <class 'numpy.ndarray'>
# ㅡㅡㅡㅡㅡjson_df['neck'].value_counts()ㅡㅡㅡㅡㅡ
# 1    10320
# 2     4710
# 2     3196
# 1     1243
# 0      290
# 0      195
#          1
# Name: neck, dtype: int64
# ㅡㅡㅡㅡㅡjson_df['neck'].value_counts(normalize=True)ㅡㅡㅡㅡㅡ
# 1    0.517164
# 2    0.236031
# 2    0.160160
# 1    0.062290
# 0    0.014533
# 0    0.009772
#      0.000050
# Name: neck, dtype: float64
# =====================trunk=====================
# ㅡㅡㅡㅡㅡjson_df[i].unique()ㅡㅡㅡㅡㅡ
# ['1' 1 '0' 0 '']
# ㅡㅡㅡㅡㅡtype(json_df[i].unique()ㅡㅡㅡㅡㅡ
# <class 'numpy.ndarray'>
# ㅡㅡㅡㅡㅡjson_df['neck'].value_counts()ㅡㅡㅡㅡㅡ
# 1    10320
# 2     4710
# 2     3196
# 1     1243
# 0      290
# 0      195
#          1
# Name: neck, dtype: int64
# ㅡㅡㅡㅡㅡjson_df['neck'].value_counts(normalize=True)ㅡㅡㅡㅡㅡ
# 1    0.517164
# 2    0.236031
# 2    0.160160
# 1    0.062290
# 0    0.014533
# 0    0.009772
#      0.000050
# Name: neck, dtype: float64
# =====================upperarm=====================
# ㅡㅡㅡㅡㅡjson_df[i].unique()ㅡㅡㅡㅡㅡ
# ['0' 0 1 '1' '2' 3 '3']
# ㅡㅡㅡㅡㅡtype(json_df[i].unique()ㅡㅡㅡㅡㅡ
# <class 'numpy.ndarray'>
# ㅡㅡㅡㅡㅡjson_df['neck'].value_counts()ㅡㅡㅡㅡㅡ
# 1    10320
# 2     4710
# 2     3196
# 1     1243
# 0      290
# 0      195
#          1
# Name: neck, dtype: int64
# ㅡㅡㅡㅡㅡjson_df['neck'].value_counts(normalize=True)ㅡㅡㅡㅡㅡ
# 1    0.517164
# 2    0.236031
# 2    0.160160
# 1    0.062290
# 0    0.014533
# 0    0.009772
#      0.000050
# Name: neck, dtype: float64
# =====================lowerarm=====================
# ㅡㅡㅡㅡㅡjson_df[i].unique()ㅡㅡㅡㅡㅡ
# ['0' 0 '1' 1 2 '2']
# ㅡㅡㅡㅡㅡtype(json_df[i].unique()ㅡㅡㅡㅡㅡ
# <class 'numpy.ndarray'>
# ㅡㅡㅡㅡㅡjson_df['neck'].value_counts()ㅡㅡㅡㅡㅡ
# 1    10320
# 2     4710
# 2     3196
# 1     1243
# 0      290
# 0      195
#          1
# Name: neck, dtype: int64
# ㅡㅡㅡㅡㅡjson_df['neck'].value_counts(normalize=True)ㅡㅡㅡㅡㅡ
# 1    0.517164
# 2    0.236031
# 2    0.160160
# 1    0.062290
# 0    0.014533
# 0    0.009772
#      0.000050
# Name: neck, dtype: float64
# =====================legs=====================
# ㅡㅡㅡㅡㅡjson_df[i].unique()ㅡㅡㅡㅡㅡ
# ['4' 4 1 '1' '2' 3 '3' 2 0 '0' '' 5 '5']
# ㅡㅡㅡㅡㅡtype(json_df[i].unique()ㅡㅡㅡㅡㅡ
# <class 'numpy.ndarray'>
# ㅡㅡㅡㅡㅡjson_df['neck'].value_counts()ㅡㅡㅡㅡㅡ
# 1    10320
# 2     4710
# 2     3196
# 1     1243
# 0      290
# 0      195
#          1
# Name: neck, dtype: int64
# ㅡㅡㅡㅡㅡjson_df['neck'].value_counts(normalize=True)ㅡㅡㅡㅡㅡ
# 1    0.517164
# 2    0.236031
# 2    0.160160
# 1    0.062290
# 0    0.014533
# 0    0.009772
#      0.000050
# Name: neck, dtype: float64

# %% [markdown]
# #### (2) Missing Value Check + Remove

# %%
for i in json_posture_keys:
    print("=====================결측치=====================")
    print(json_df[json_df[i] == ''])
    json_df = json_df[json_df[i] != '']
# Out:
# =====================결측치=====================
#                                                 neck trunk upperarm lowerarm  \
# F01_P001_A2_W001_D2022-08-23-10-23-00_0499.json                   3        1
#
#                                                 legs json_trunk_twist  bbox_w  \
# F01_P001_A2_W001_D2022-08-23-10-23-00_0499.json                     0   521.6
#
#                                                  bbox_h  x1  y1  ...  y13  \
# F01_P001_A2_W001_D2022-08-23-10-23-00_0499.json   460.8  24  89  ...  115
#
#                                                  x14  y14  x15  y15  x16  y16  \
# F01_P001_A2_W001_D2022-08-23-10-23-00_0499.json   67  116   65  116  104   93
#
#                                                  x17  y17  \
# F01_P001_A2_W001_D2022-08-23-10-23-00_0499.json  101   95
#
#                                                                                        json_path
# F01_P001_A2_W001_D2022-08-23-10-23-00_0499.json  F01_P001_A2_W001_D2022-08-23-10-23-00_0499.json
#
# [1 rows x 43 columns]
# =====================결측치=====================
# Empty DataFrame
# Columns: [neck, trunk, upperarm, lowerarm, legs, json_trunk_twist, bbox_w, bbox_h, x1, y1, x2, y2, x3, y3, x4, y4, x5, y5, x6, y6, x7, y7, x8, y8, x9, y9, x10, y10, x11, y11, x12, y12, x13, y13, x14, y14, x15, y15, x16, y16, x17, y17, json_path]
# Index: []
#
# [0 rows x 43 columns]
# =====================결측치=====================
# Empty DataFrame
# Columns: [neck, trunk, upperarm, lowerarm, legs, json_trunk_twist, bbox_w, bbox_h, x1, y1, x2, y2, x3, y3, x4, y4, x5, y5, x6, y6, x7, y7, x8, y8, x9, y9, x10, y10, x11, y11, x12, y12, x13, y13, x14, y14, x15, y15, x16, y16, x17, y17, json_path]
# Index: []
#
# [0 rows x 43 columns]
# =====================결측치=====================
# Empty DataFrame
# Columns: [neck, trunk, upperarm, lowerarm, legs, json_trunk_twist, bbox_w, bbox_h, x1, y1, x2, y2, x3, y3, x4, y4, x5, y5, x6, y6, x7, y7, x8, y8, x9, y9, x10, y10, x11, y11, x12, y12, x13, y13, x14, y14, x15, y15, x16, y16, x17, y17, json_path]
# Index: []
#
# [0 rows x 43 columns]
# =====================결측치=====================
# Empty DataFrame
# Columns: [neck, trunk, upperarm, lowerarm, legs, json_trunk_twist, bbox_w, bbox_h, x1, y1, x2, y2, x3, y3, x4, y4, x5, y5, x6, y6, x7, y7, x8, y8, x9, y9, x10, y10, x11, y11, x12, y12, x13, y13, x14, y14, x15, y15, x16, y16, x17, y17, json_path]
# Index: []
#
# [0 rows x 43 columns]

# %%
for i in json_posture_keys:
    print(f"====================={i}=====================")
    print("ㅡㅡㅡㅡㅡjson_df[i].unique()ㅡㅡㅡㅡㅡ")
    print(json_df[i].unique())
    print("ㅡㅡㅡㅡㅡtype(json_df[i].unique()ㅡㅡㅡㅡㅡ")
    print(type(json_df[i].unique()))
    print("ㅡㅡㅡㅡㅡjson_df['neck'].value_counts()ㅡㅡㅡㅡㅡ")
    print(json_df['neck'].value_counts())
    print("ㅡㅡㅡㅡㅡjson_df['neck'].value_counts(normalize=True)ㅡㅡㅡㅡㅡ")
    print(json_df['neck'].value_counts(normalize=True))
# Out:
# =====================neck=====================
# ㅡㅡㅡㅡㅡjson_df[i].unique()ㅡㅡㅡㅡㅡ
# ['2' 2 '1' 1 '0' 0]
# ㅡㅡㅡㅡㅡtype(json_df[i].unique()ㅡㅡㅡㅡㅡ
# <class 'numpy.ndarray'>
# ㅡㅡㅡㅡㅡjson_df['neck'].value_counts()ㅡㅡㅡㅡㅡ
# 1    10320
# 2     4710
# 2     3196
# 1     1243
# 0      290
# 0      195
# Name: neck, dtype: int64
# ㅡㅡㅡㅡㅡjson_df['neck'].value_counts(normalize=True)ㅡㅡㅡㅡㅡ
# 1    0.517190
# 2    0.236043
# 2    0.160168
# 1    0.062293
# 0    0.014533
# 0    0.009772
# Name: neck, dtype: float64
# =====================trunk=====================
# ㅡㅡㅡㅡㅡjson_df[i].unique()ㅡㅡㅡㅡㅡ
# ['1' 1 '0' 0]
# ㅡㅡㅡㅡㅡtype(json_df[i].unique()ㅡㅡㅡㅡㅡ
# <class 'numpy.ndarray'>
# ㅡㅡㅡㅡㅡjson_df['neck'].value_counts()ㅡㅡㅡㅡㅡ
# 1    10320
# 2     4710
# 2     3196
# 1     1243
# 0      290
# 0      195
# Name: neck, dtype: int64
# ㅡㅡㅡㅡㅡjson_df['neck'].value_counts(normalize=True)ㅡㅡㅡㅡㅡ
# 1    0.517190
# 2    0.236043
# 2    0.160168
# 1    0.062293
# 0    0.014533
# 0    0.009772
# Name: neck, dtype: float64
# =====================upperarm=====================
# ㅡㅡㅡㅡㅡjson_df[i].unique()ㅡㅡㅡㅡㅡ
# ['0' 0 1 '1' '2' 3 '3']
# ㅡㅡㅡㅡㅡtype(json_df[i].unique()ㅡㅡㅡㅡㅡ
# <class 'numpy.ndarray'>
# ㅡㅡㅡㅡㅡjson_df['neck'].value_counts()ㅡㅡㅡㅡㅡ
# 1    10320
# 2     4710
# 2     3196
# 1     1243
# 0      290
# 0      195
# Name: neck, dtype: int64
# ㅡㅡㅡㅡㅡjson_df['neck'].value_counts(normalize=True)ㅡㅡㅡㅡㅡ
# 1    0.517190
# 2    0.236043
# 2    0.160168
# 1    0.062293
# 0    0.014533
# 0    0.009772
# Name: neck, dtype: float64
# =====================lowerarm=====================
# ㅡㅡㅡㅡㅡjson_df[i].unique()ㅡㅡㅡㅡㅡ
# ['0' 0 '1' 1 2 '2']
# ㅡㅡㅡㅡㅡtype(json_df[i].unique()ㅡㅡㅡㅡㅡ
# <class 'numpy.ndarray'>
# ㅡㅡㅡㅡㅡjson_df['neck'].value_counts()ㅡㅡㅡㅡㅡ
# 1    10320
# 2     4710
# 2     3196
# 1     1243
# 0      290
# 0      195
# Name: neck, dtype: int64
# ㅡㅡㅡㅡㅡjson_df['neck'].value_counts(normalize=True)ㅡㅡㅡㅡㅡ
# 1    0.517190
# 2    0.236043
# 2    0.160168
# 1    0.062293
# 0    0.014533
# 0    0.009772
# Name: neck, dtype: float64
# =====================legs=====================
# ㅡㅡㅡㅡㅡjson_df[i].unique()ㅡㅡㅡㅡㅡ
# ['4' 4 1 '1' '2' 3 '3' 2 0 '0' 5 '5']
# ㅡㅡㅡㅡㅡtype(json_df[i].unique()ㅡㅡㅡㅡㅡ
# <class 'numpy.ndarray'>
# ㅡㅡㅡㅡㅡjson_df['neck'].value_counts()ㅡㅡㅡㅡㅡ
# 1    10320
# 2     4710
# 2     3196
# 1     1243
# 0      290
# 0      195
# Name: neck, dtype: int64
# ㅡㅡㅡㅡㅡjson_df['neck'].value_counts(normalize=True)ㅡㅡㅡㅡㅡ
# 1    0.517190
# 2    0.236043
# 2    0.160168
# 1    0.062293
# 0    0.014533
# 0    0.009772
# Name: neck, dtype: float64

# %% [markdown]
# #### (4) Type Unification

# %%
json_df = json_df.astype({'neck':int, 'trunk':int, 'upperarm':int, 'lowerarm':int, 'legs':int, 'json_trunk_twist':int})

# %%
json_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19954 entries, F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json to F05_P001_A3_W001_D2022-09-23-10-23-27_0618.json
# Data columns (total 43 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   neck              19954 non-null  int32
#  1   trunk             19954 non-null  int32
#  2   upperarm          19954 non-null  int32
#  3   lowerarm          19954 non-null  int32
#  4   legs              19954 non-null  int32
#  5   json_trunk_twist  19954 non-null  int32
#  6   bbox_w            19954 non-null  float64
#  7   bbox_h            19954 non-null  float64
#  8   x1                19954 non-null  int64
#  9   y1                19954 non-null  int64
#  10  x2                19954 non-null  int64
#  11  y2                19954 non-null  int64
#  12  x3                19954 non-null  int64
#  13  y3                19954 non-null  int64
#  14  x4                19954 non-null  int64
#  15  y4                19954 non-null  int64
#  16  x5                19954 non-null  int64
#  17  y5                19954 non-null  int64
#  18  x6                19954 non-null  int64
#  19  y6                19954 non-null  int64
#  20  x7                19954 non-null  int64
#  21  y7                19954 non-null  int64
#  22  x8                19954 non-null  int64
#  23  y8                19954 non-null  int64
#  24  x9                19954 non-null  int64
#  25  y9                19954 non-null  int64
#  26  x10               19954 non-null  int64
#  27  y10               19954 non-null  int64
#  28  x11               19954 non-null  int64
#  29  y11               19954 non-null  int64
#  30  x12               19954 non-null  int64
#  31  y12               19954 non-null  int64
#  32  x13               19954 non-null  int64
#  33  y13               19954 non-null  int64
#  34  x14               19954 non-null  int64
#  35  y14               19954 non-null  int64
#  36  x15               19954 non-null  int64
#  37  y15               19954 non-null  int64
#  38  x16               19954 non-null  int64
#  39  y16               19954 non-null  int64
#  40  x17               19954 non-null  int64
#  41  y17               19954 non-null  int64
#  42  json_path         19954 non-null  object
# dtypes: float64(2), int32(6), int64(34), object(1)
# memory usage: 6.2+ MB

# %% [markdown]
# #### (5) Skeleton Resize

# %%
json_df[json_skeleton_keys]
# Out:
#                                                   x1  y1   x2  y2  x3  y3  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json   89  56   91  52  93  54
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json   87  41   88  37  91  40
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json   84  51   83  46  84  48
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json   72  56   69  51  72  52
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json   83 -67   76 -67  78 -67
# ...                                              ...  ..  ...  ..  ..  ..
# F05_P001_A3_W001_D2022-09-23-10-23-27_0614.json   93  81   93  77  90  76
# F05_P001_A3_W001_D2022-09-23-10-23-27_0615.json   79  59   85  55  77  54
# F05_P001_A3_W001_D2022-09-23-10-23-27_0616.json   93  59   97  56  91  56
# F05_P001_A3_W001_D2022-09-23-10-23-27_0617.json  101  65  107  62  98  60
# F05_P001_A3_W001_D2022-09-23-10-23-27_0618.json  100  68  106  64  97  62
#
#                                                   x4  y4  x5  y5  ...  x13  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json   92  46  93  48  ...   47
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json   85  34  93  39  ...   52
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json   76  41  81  44  ...   51
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json   59  48  67  50  ...   53
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json   77 -68  83 -49  ...   46
# ...                                              ...  ..  ..  ..  ...  ...
# F05_P001_A3_W001_D2022-09-23-10-23-27_0614.json   85  71  77  71  ...   57
# F05_P001_A3_W001_D2022-09-23-10-23-27_0615.json   94  57  75  56  ...   62
# F05_P001_A3_W001_D2022-09-23-10-23-27_0616.json  105  63  91  59  ...   70
# F05_P001_A3_W001_D2022-09-23-10-23-27_0617.json  114  65  91  59  ...   75
# F05_P001_A3_W001_D2022-09-23-10-23-27_0618.json  113  65  92  60  ...   74
#
#                                                  y13  x14  y14  x15  y15  x16  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json   75   53  104   55  127   55
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json   82   53  133   56  134   55
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json  114   54  165   53  166   50
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json  141   56  189   57  188   52
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json   16   46    4   70   14   31
# ...                                              ...  ...  ...  ...  ...  ...
# F05_P001_A3_W001_D2022-09-23-10-23-27_0614.json  182   79  247   54  255   85
# F05_P001_A3_W001_D2022-09-23-10-23-27_0615.json  170   90  241   60  244   88
# F05_P001_A3_W001_D2022-09-23-10-23-27_0616.json  174   96  248   65  249   92
# F05_P001_A3_W001_D2022-09-23-10-23-27_0617.json  173   97  245   69  247   93
# F05_P001_A3_W001_D2022-09-23-10-23-27_0618.json  176   96  245   67  246   92
#
#                                                  y16  x17  y17
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json  142   57  168
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json  171   57  173
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json  211   51  209
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json  237   51  236
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json   19   43   25
# ...                                              ...  ...  ...
# F05_P001_A3_W001_D2022-09-23-10-23-27_0614.json  300   52  316
# F05_P001_A3_W001_D2022-09-23-10-23-27_0615.json  305   58  311
# F05_P001_A3_W001_D2022-09-23-10-23-27_0616.json  315   60  316
# F05_P001_A3_W001_D2022-09-23-10-23-27_0617.json  308   64  310
# F05_P001_A3_W001_D2022-09-23-10-23-27_0618.json  309   63  311
#
# [19954 rows x 34 columns]

# %%
json_df.columns
# Out:
# Index(['neck', 'trunk', 'upperarm', 'lowerarm', 'legs', 'json_trunk_twist',
#        'bbox_w', 'bbox_h', 'x1', 'y1', 'x2', 'y2', 'x3', 'y3', 'x4', 'y4',
#        'x5', 'y5', 'x6', 'y6', 'x7', 'y7', 'x8', 'y8', 'x9', 'y9', 'x10',
#        'y10', 'x11', 'y11', 'x12', 'y12', 'x13', 'y13', 'x14', 'y14', 'x15',
#        'y15', 'x16', 'y16', 'x17', 'y17', 'json_path'],
#       dtype='object')

# %%
x_index = [i for i in json_df.columns if "x" in i]

x_index
# Out:
# ['bbox_w',
#  'bbox_h',
#  'x1',
#  'x2',
#  'x3',
#  'x4',
#  'x5',
#  'x6',
#  'x7',
#  'x8',
#  'x9',
#  'x10',
#  'x11',
#  'x12',
#  'x13',
#  'x14',
#  'x15',
#  'x16',
#  'x17']

# %%
json_df.head()
# Out:
#                                                  neck  trunk  upperarm  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json     2      1         0
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json     2      1         0
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json     2      1         0
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json     1      0         0
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json     1      0         1
#
#                                                  lowerarm  legs  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json         0     4
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json         0     4
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json         0     4
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json         1     4
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json         0     1
#
#                                                  json_trunk_twist  bbox_w  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json                 1   434.4
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json                 0   428.0
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json                 0   398.4
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json                 0   365.6
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json                 0   457.6
#
#                                                  bbox_h  x1  y1  ...  y13  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json   712.8  89  56  ...   75
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json   742.4  87  41  ...   82
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json   901.6  84  51  ...  114
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json  1016.8  72  56  ...  141
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json  1098.4  83 -67  ...   16
#
#                                                  x14  y14  x15  y15  x16  y16  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json   53  104   55  127   55  142
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json   53  133   56  134   55  171
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json   54  165   53  166   50  211
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json   56  189   57  188   52  237
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json   46    4   70   14   31   19
#
#                                                  x17  y17  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json   57  168
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json   57  173
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json   51  209
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json   51  236
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json   43   25
#
#                                                                                        json_path
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json  F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json  F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json  F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json  F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json  F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json
#
# [5 rows x 43 columns]

# %%
json_df[x_index] = json_df[x_index] * 6

# %%
json_df.head()
# Out:
#                                                  neck  trunk  upperarm  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json     2      1         0
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json     2      1         0
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json     2      1         0
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json     1      0         0
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json     1      0         1
#
#                                                  lowerarm  legs  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json         0     4
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json         0     4
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json         0     4
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json         1     4
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json         0     1
#
#                                                  json_trunk_twist  bbox_w  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json                 1  2606.4
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json                 0  2568.0
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json                 0  2390.4
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json                 0  2193.6
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json                 0  2745.6
#
#                                                  bbox_h   x1  y1  ...  y13  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json  4276.8  534  56  ...   75
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json  4454.4  522  41  ...   82
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json  5409.6  504  51  ...  114
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json  6100.8  432  56  ...  141
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json  6590.4  498 -67  ...   16
#
#                                                  x14  y14  x15  y15  x16  y16  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json  318  104  330  127  330  142
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json  318  133  336  134  330  171
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json  324  165  318  166  300  211
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json  336  189  342  188  312  237
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json  276    4  420   14  186   19
#
#                                                  x17  y17  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json  342  168
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json  342  173
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json  306  209
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json  306  236
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json  258   25
#
#                                                                                        json_path
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json  F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json  F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json  F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json  F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json  F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json
#
# [5 rows x 43 columns]

# %%
y_index = [i for i in json_df.columns if "y" in i]

y_index
# Out:
# ['y1',
#  'y2',
#  'y3',
#  'y4',
#  'y5',
#  'y6',
#  'y7',
#  'y8',
#  'y9',
#  'y10',
#  'y11',
#  'y12',
#  'y13',
#  'y14',
#  'y15',
#  'y16',
#  'y17']

# %%
json_df[y_index] = json_df[y_index] * 4.5

# %%
json_df.head()
# Out:
#                                                  neck  trunk  upperarm  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json     2      1         0
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json     2      1         0
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json     2      1         0
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json     1      0         0
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json     1      0         1
#
#                                                  lowerarm  legs  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json         0     4
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json         0     4
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json         0     4
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json         1     4
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json         0     1
#
#                                                  json_trunk_twist  bbox_w  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json                 1  2606.4
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json                 0  2568.0
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json                 0  2390.4
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json                 0  2193.6
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json                 0  2745.6
#
#                                                  bbox_h   x1     y1  ...  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json  4276.8  534  252.0  ...
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json  4454.4  522  184.5  ...
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json  5409.6  504  229.5  ...
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json  6100.8  432  252.0  ...
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json  6590.4  498 -301.5  ...
#
#                                                    y13  x14    y14  x15  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json  337.5  318  468.0  330
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json  369.0  318  598.5  336
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json  513.0  324  742.5  318
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json  634.5  336  850.5  342
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json   72.0  276   18.0  420
#
#                                                    y15  x16     y16  x17  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json  571.5  330   639.0  342
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json  603.0  330   769.5  342
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json  747.0  300   949.5  306
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json  846.0  312  1066.5  306
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json   63.0  186    85.5  258
#
#                                                     y17  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json   756.0
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json   778.5
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json   940.5
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json  1062.0
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json   112.5
#
#                                                                                        json_path
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json  F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json  F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json  F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json  F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json  F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json
#
# [5 rows x 43 columns]

# %%
json_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19954 entries, F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json to F05_P001_A3_W001_D2022-09-23-10-23-27_0618.json
# Data columns (total 43 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   neck              19954 non-null  int32
#  1   trunk             19954 non-null  int32
#  2   upperarm          19954 non-null  int32
#  3   lowerarm          19954 non-null  int32
#  4   legs              19954 non-null  int32
#  5   json_trunk_twist  19954 non-null  int32
#  6   bbox_w            19954 non-null  float64
#  7   bbox_h            19954 non-null  float64
#  8   x1                19954 non-null  int64
#  9   y1                19954 non-null  float64
#  10  x2                19954 non-null  int64
#  11  y2                19954 non-null  float64
#  12  x3                19954 non-null  int64
#  13  y3                19954 non-null  float64
#  14  x4                19954 non-null  int64
#  15  y4                19954 non-null  float64
#  16  x5                19954 non-null  int64
#  17  y5                19954 non-null  float64
#  18  x6                19954 non-null  int64
#  19  y6                19954 non-null  float64
#  20  x7                19954 non-null  int64
#  21  y7                19954 non-null  float64
#  22  x8                19954 non-null  int64
#  23  y8                19954 non-null  float64
#  24  x9                19954 non-null  int64
#  25  y9                19954 non-null  float64
#  26  x10               19954 non-null  int64
#  27  y10               19954 non-null  float64
#  28  x11               19954 non-null  int64
#  29  y11               19954 non-null  float64
#  30  x12               19954 non-null  int64
#  31  y12               19954 non-null  float64
#  32  x13               19954 non-null  int64
#  33  y13               19954 non-null  float64
#  34  x14               19954 non-null  int64
#  35  y14               19954 non-null  float64
#  36  x15               19954 non-null  int64
#  37  y15               19954 non-null  float64
#  38  x16               19954 non-null  int64
#  39  y16               19954 non-null  float64
#  40  x17               19954 non-null  int64
#  41  y17               19954 non-null  float64
#  42  json_path         19954 non-null  object
# dtypes: float64(19), int32(6), int64(17), object(1)
# memory usage: 6.2+ MB

# %%
json_df[x_index] = json_df[x_index].astype('int')
json_df[y_index] = json_df[y_index].astype('int')

# %%
json_df.head()
# Out:
#                                                  neck  trunk  upperarm  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json     2      1         0
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json     2      1         0
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json     2      1         0
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json     1      0         0
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json     1      0         1
#
#                                                  lowerarm  legs  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json         0     4
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json         0     4
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json         0     4
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json         1     4
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json         0     1
#
#                                                  json_trunk_twist  bbox_w  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json                 1    2606
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json                 0    2568
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json                 0    2390
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json                 0    2193
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json                 0    2745
#
#                                                  bbox_h   x1   y1  ...  y13  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json    4276  534  252  ...  337
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json    4454  522  184  ...  369
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json    5409  504  229  ...  513
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json    6100  432  252  ...  634
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json    6590  498 -301  ...   72
#
#                                                  x14  y14  x15  y15  x16  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json  318  468  330  571  330
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json  318  598  336  603  330
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json  324  742  318  747  300
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json  336  850  342  846  312
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json  276   18  420   63  186
#
#                                                   y16  x17   y17  \
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json   639  342   756
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json   769  342   778
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json   949  306   940
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json  1066  306  1062
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json    85  258   112
#
#                                                                                        json_path
# F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json  F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json
# F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json  F01_P001_A1_W001_D2022-08-23-10-12-00_0003.json
# F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json  F01_P001_A1_W001_D2022-08-23-10-12-00_0004.json
# F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json  F01_P001_A1_W001_D2022-08-23-10-12-00_0005.json
# F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json  F01_P001_A1_W001_D2022-08-23-10-12-00_0006.json
#
# [5 rows x 43 columns]

# %%
json_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19954 entries, F01_P001_A1_W001_D2022-08-23-10-12-00_0002.json to F05_P001_A3_W001_D2022-09-23-10-23-27_0618.json
# Data columns (total 43 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   neck              19954 non-null  int32
#  1   trunk             19954 non-null  int32
#  2   upperarm          19954 non-null  int32
#  3   lowerarm          19954 non-null  int32
#  4   legs              19954 non-null  int32
#  5   json_trunk_twist  19954 non-null  int32
#  6   bbox_w            19954 non-null  int32
#  7   bbox_h            19954 non-null  int32
#  8   x1                19954 non-null  int32
#  9   y1                19954 non-null  int32
#  10  x2                19954 non-null  int32
#  11  y2                19954 non-null  int32
#  12  x3                19954 non-null  int32
#  13  y3                19954 non-null  int32
#  14  x4                19954 non-null  int32
#  15  y4                19954 non-null  int32
#  16  x5                19954 non-null  int32
#  17  y5                19954 non-null  int32
#  18  x6                19954 non-null  int32
#  19  y6                19954 non-null  int32
#  20  x7                19954 non-null  int32
#  21  y7                19954 non-null  int32
#  22  x8                19954 non-null  int32
#  23  y8                19954 non-null  int32
#  24  x9                19954 non-null  int32
#  25  y9                19954 non-null  int32
#  26  x10               19954 non-null  int32
#  27  y10               19954 non-null  int32
#  28  x11               19954 non-null  int32
#  29  y11               19954 non-null  int32
#  30  x12               19954 non-null  int32
#  31  y12               19954 non-null  int32
#  32  x13               19954 non-null  int32
#  33  y13               19954 non-null  int32
#  34  x14               19954 non-null  int32
#  35  y14               19954 non-null  int32
#  36  x15               19954 non-null  int32
#  37  y15               19954 non-null  int32
#  38  x16               19954 non-null  int32
#  39  y16               19954 non-null  int32
#  40  x17               19954 non-null  int32
#  41  y17               19954 non-null  int32
#  42  json_path         19954 non-null  object
# dtypes: int32(42), object(1)
# memory usage: 3.5+ MB

# %% [markdown]
# ## 3. Train Val Test Split

# %% [markdown]
# ### 1) split_list list

# %%
split_list = os.listdir(args.split_list_path)

split_list
# Out:
# ['test_split_list.txt', 'train_split_list.txt', 'val_split_list.txt']

# %% [markdown]
# ### 2) Error list

# %%
with open(args.error_list_txt_path, 'r') as error_open:
    error_json_list = error_open.readlines()

# %% [markdown]
# ### 3) JSON -> DF(train & val & test) Split

# %%
for i, split_file in enumerate(split_list):
    split_full_path = args.split_list_path+split_file
    with open(split_full_path, 'r') as split_open:
        split_json_list = split_open.readlines()
        print("len(split_json_list) : ", len(split_json_list))
        for j, split_json_file in enumerate(split_json_list):
            try:
                split_slice_file = split_json_file[split_json_file.find('F'):split_json_file.find('jpg')-1]
                json_file = split_slice_file + ".json"
                one_split_series = json_df.loc[json_file]
                one_split_df = pd.DataFrame([one_split_series])
#                 print("type(one_split_df) : ", type(one_split_df))
#                 print("type([one_split_df]) : ", type([one_split_df]))
#                 print("type(pd.DataFrame([one_split_df]) : ", type(pd.DataFrame([one_split_df])))
                if j==0:
                    globals()[f"{split_file[:-15]}_df"] = one_split_df
                else:
                    globals()[f"{split_file[:-15]}_df"] = pd.concat([globals()[f"{split_file[:-15]}_df"], one_split_df])
            except:
                if json_file in error_json_list:
                    print("error file(if) : ", json_file)
                else:
                    print("error file(else) : ", json_file)
#     print("globals()[f"{split_file[:-15]}_df"] : ", globals()[f"{split_file[:-15]}_df"])
#             if j==20:
#                 break
# Out:
# len(split_json_list) :  1996
# error file(else) :  F04_P001_A1_W001_D2022-09-16-09-53-48_0748.json
# len(split_json_list) :  15968
# error file(else) :  F04_P001_A2_W001_D2022-09-16-10-13-12_1851.json
# error file(else) :  F03_P001_A1_W001_D2022-09-30-13-09-04_0489.json
# error file(else) :  F04_P001_A2_W001_D2022-09-16-10-13-12_1842.json
# error file(else) :  F01_P001_A1_W001_D2022-08-23-10-12-00_0001.json
# error file(else) :  F01_P001_A2_W001_D2022-08-23-10-23-00_0499.json
# len(split_json_list) :  1997
# error file(else) :  F01_P001_A1_W001_D2022-08-23-10-22-00_0445.json

# %% [markdown]
# ### 4) Visualization

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15963 entries, F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json to F02_P001_A1_W001_D2022-08-24-11-15-55_1409.json
# Data columns (total 43 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   neck              15963 non-null  int32
#  1   trunk             15963 non-null  int32
#  2   upperarm          15963 non-null  int32
#  3   lowerarm          15963 non-null  int32
#  4   legs              15963 non-null  int32
#  5   json_trunk_twist  15963 non-null  int32
#  6   bbox_w            15963 non-null  int32
#  7   bbox_h            15963 non-null  int32
#  8   x1                15963 non-null  int32
#  9   y1                15963 non-null  int32
#  10  x2                15963 non-null  int32
#  11  y2                15963 non-null  int32
#  12  x3                15963 non-null  int32
#  13  y3                15963 non-null  int32
#  14  x4                15963 non-null  int32
#  15  y4                15963 non-null  int32
#  16  x5                15963 non-null  int32
#  17  y5                15963 non-null  int32
#  18  x6                15963 non-null  int32
#  19  y6                15963 non-null  int32
#  20  x7                15963 non-null  int32
#  21  y7                15963 non-null  int32
#  22  x8                15963 non-null  int32
#  23  y8                15963 non-null  int32
#  24  x9                15963 non-null  int32
#  25  y9                15963 non-null  int32
#  26  x10               15963 non-null  int32
#  27  y10               15963 non-null  int32
#  28  x11               15963 non-null  int32
#  29  y11               15963 non-null  int32
#  30  x12               15963 non-null  int32
#  31  y12               15963 non-null  int32
#  32  x13               15963 non-null  int32
#  33  y13               15963 non-null  int32
#  34  x14               15963 non-null  int32
#  35  y14               15963 non-null  int32
#  36  x15               15963 non-null  int32
#  37  y15               15963 non-null  int32
#  38  x16               15963 non-null  int32
#  39  y16               15963 non-null  int32
#  40  x17               15963 non-null  int32
#  41  y17               15963 non-null  int32
#  42  json_path         15963 non-null  object
# dtypes: int32(42), object(1)
# memory usage: 2.8+ MB

# %%
train_df.shape
# Out:
# (15963, 43)

# %%
train_df.head()
# Out:
#                                                  neck  trunk  upperarm  \
# F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json     2      0         0
# F04_P001_A2_W001_D2022-09-16-10-13-12_3092.json     1      1         0
# F02_P001_A1_W001_D2022-08-24-11-15-55_1464.json     2      0         0
# F03_P001_A1_W001_D2022-09-30-13-09-04_0345.json     1      0         1
# F04_P001_A1_W001_D2022-09-16-09-53-48_0431.json     2      1         0
#
#                                                  lowerarm  legs  \
# F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json         0     1
# F04_P001_A2_W001_D2022-09-16-10-13-12_3092.json         0     1
# F02_P001_A1_W001_D2022-08-24-11-15-55_1464.json         0     1
# F03_P001_A1_W001_D2022-09-30-13-09-04_0345.json         0     1
# F04_P001_A1_W001_D2022-09-16-09-53-48_0431.json         0     0
#
#                                                  json_trunk_twist  bbox_w  \
# F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json                 0    4507
# F04_P001_A2_W001_D2022-09-16-10-13-12_3092.json                 1    4233
# F02_P001_A1_W001_D2022-08-24-11-15-55_1464.json                 0    8760
# F03_P001_A1_W001_D2022-09-30-13-09-04_0345.json                 0    2260
# F04_P001_A1_W001_D2022-09-16-09-53-48_0431.json                 0    2270
#
#                                                  bbox_h   x1   y1  ...   y13  \
# F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json    7267  504  463  ...  1111
# F04_P001_A2_W001_D2022-09-16-10-13-12_3092.json    3259  738  319  ...   459
# F02_P001_A1_W001_D2022-08-24-11-15-55_1464.json    7344  684  486  ...  1264
# F03_P001_A1_W001_D2022-09-30-13-09-04_0345.json    5505  390  252  ...   580
# F04_P001_A1_W001_D2022-09-16-09-53-48_0431.json    2606  378  229  ...   364
#
#                                                  x14   y14  x15   y15  x16  \
# F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json  756  1426  366  1435  738
# F04_P001_A2_W001_D2022-09-16-10-13-12_3092.json  576   634  342   661  546
# F02_P001_A1_W001_D2022-08-24-11-15-55_1464.json  810  1494  582  1494  822
# F03_P001_A1_W001_D2022-09-30-13-09-04_0345.json  432   738  294   751  444
# F04_P001_A1_W001_D2022-09-16-09-53-48_0431.json  468   342  282   369  414
#
#                                                   y16  x17   y17  \
# F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json  1444  408  1435
# F04_P001_A2_W001_D2022-09-16-10-13-12_3092.json   742  210   639
# F02_P001_A1_W001_D2022-08-24-11-15-55_1464.json  1503  612  1512
# F03_P001_A1_W001_D2022-09-30-13-09-04_0345.json   936  240   949
# F04_P001_A1_W001_D2022-09-16-09-53-48_0431.json   504  282   522
#
#                                                                                        json_path
# F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json  F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json
# F04_P001_A2_W001_D2022-09-16-10-13-12_3092.json  F04_P001_A2_W001_D2022-09-16-10-13-12_3092.json
# F02_P001_A1_W001_D2022-08-24-11-15-55_1464.json  F02_P001_A1_W001_D2022-08-24-11-15-55_1464.json
# F03_P001_A1_W001_D2022-09-30-13-09-04_0345.json  F03_P001_A1_W001_D2022-09-30-13-09-04_0345.json
# F04_P001_A1_W001_D2022-09-16-09-53-48_0431.json  F04_P001_A1_W001_D2022-09-16-09-53-48_0431.json
#
# [5 rows x 43 columns]

# %%
# train_df

# %%
val_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1996 entries, F03_P002_A1_W002_D2022-08-25-11-08-08_1146.json to F04_P001_A2_W001_D2022-09-16-10-13-12_0782.json
# Data columns (total 43 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   neck              1996 non-null   int32
#  1   trunk             1996 non-null   int32
#  2   upperarm          1996 non-null   int32
#  3   lowerarm          1996 non-null   int32
#  4   legs              1996 non-null   int32
#  5   json_trunk_twist  1996 non-null   int32
#  6   bbox_w            1996 non-null   int32
#  7   bbox_h            1996 non-null   int32
#  8   x1                1996 non-null   int32
#  9   y1                1996 non-null   int32
#  10  x2                1996 non-null   int32
#  11  y2                1996 non-null   int32
#  12  x3                1996 non-null   int32
#  13  y3                1996 non-null   int32
#  14  x4                1996 non-null   int32
#  15  y4                1996 non-null   int32
#  16  x5                1996 non-null   int32
#  17  y5                1996 non-null   int32
#  18  x6                1996 non-null   int32
#  19  y6                1996 non-null   int32
#  20  x7                1996 non-null   int32
#  21  y7                1996 non-null   int32
#  22  x8                1996 non-null   int32
#  23  y8                1996 non-null   int32
#  24  x9                1996 non-null   int32
#  25  y9                1996 non-null   int32
#  26  x10               1996 non-null   int32
#  27  y10               1996 non-null   int32
#  28  x11               1996 non-null   int32
#  29  y11               1996 non-null   int32
#  30  x12               1996 non-null   int32
#  31  y12               1996 non-null   int32
#  32  x13               1996 non-null   int32
#  33  y13               1996 non-null   int32
#  34  x14               1996 non-null   int32
#  35  y14               1996 non-null   int32
#  36  x15               1996 non-null   int32
#  37  y15               1996 non-null   int32
#  38  x16               1996 non-null   int32
#  39  y16               1996 non-null   int32
#  40  x17               1996 non-null   int32
#  41  y17               1996 non-null   int32
#  42  json_path         1996 non-null   object
# dtypes: int32(42), object(1)
# memory usage: 358.7+ KB

# %%
val_df.shape
# Out:
# (1996, 43)

# %%
val_df.head()
# Out:
#                                                  neck  trunk  upperarm  \
# F03_P002_A1_W002_D2022-08-25-11-08-08_1146.json     1      0         1
# F02_P001_A2_W001_D2022-08-24-11-14-47_1172.json     2      0         1
# F03_P002_A2_W002_D2022-08-25-11-08-40_0079.json     1      0         1
# F02_P001_A1_W001_D2022-08-24-11-15-55_1762.json     1      0         1
# F04_P001_A1_W001_D2022-09-16-09-53-48_0925.json     1      1         0
#
#                                                  lowerarm  legs  \
# F03_P002_A1_W002_D2022-08-25-11-08-08_1146.json         0     1
# F02_P001_A2_W001_D2022-08-24-11-14-47_1172.json         0     1
# F03_P002_A2_W002_D2022-08-25-11-08-40_0079.json         0     1
# F02_P001_A1_W001_D2022-08-24-11-15-55_1762.json         0     3
# F04_P001_A1_W001_D2022-09-16-09-53-48_0925.json         1     4
#
#                                                  json_trunk_twist  bbox_w  \
# F03_P002_A1_W002_D2022-08-25-11-08-08_1146.json                 0    1780
# F02_P001_A2_W001_D2022-08-24-11-14-47_1172.json                 0    3614
# F03_P002_A2_W002_D2022-08-25-11-08-40_0079.json                 0    3091
# F02_P001_A1_W001_D2022-08-24-11-15-55_1762.json                 1    5760
# F04_P001_A1_W001_D2022-09-16-09-53-48_0925.json                 0    4353
#
#                                                  bbox_h   x1   y1  ...   y13  \
# F03_P002_A1_W002_D2022-08-25-11-08-08_1146.json    3883  378  202  ...   450
# F02_P001_A2_W001_D2022-08-24-11-14-47_1172.json   11961  648    4  ...    45
# F03_P002_A2_W002_D2022-08-25-11-08-40_0079.json    3955  396  234  ...   616
# F02_P001_A1_W001_D2022-08-24-11-15-55_1762.json    6907  516  405  ...  1107
# F04_P001_A1_W001_D2022-09-16-09-53-48_0925.json    2923  510  319  ...   432
#
#                                                  x14   y14  x15   y15  x16  \
# F03_P002_A1_W002_D2022-08-25-11-08-08_1146.json  348   580  372   580  288
# F02_P001_A2_W001_D2022-08-24-11-14-47_1172.json  666    22  594    18  642
# F03_P002_A2_W002_D2022-08-25-11-08-40_0079.json  216   535  588   535  288
# F02_P001_A1_W001_D2022-08-24-11-15-55_1762.json  276  1120  264  1107  726
# F04_P001_A1_W001_D2022-09-16-09-53-48_0925.json  840   540  510   490  828
#
#                                                   y16  x17   y17  \
# F03_P002_A1_W002_D2022-08-25-11-08-08_1146.json   702  264   697
# F02_P001_A2_W001_D2022-08-24-11-14-47_1172.json     0  594     0
# F03_P002_A2_W002_D2022-08-25-11-08-40_0079.json   724  528   720
# F02_P001_A1_W001_D2022-08-24-11-15-55_1762.json  1417  300  1246
# F04_P001_A1_W001_D2022-09-16-09-53-48_0925.json   630  624   630
#
#                                                                                        json_path
# F03_P002_A1_W002_D2022-08-25-11-08-08_1146.json  F03_P002_A1_W002_D2022-08-25-11-08-08_1146.json
# F02_P001_A2_W001_D2022-08-24-11-14-47_1172.json  F02_P001_A2_W001_D2022-08-24-11-14-47_1172.json
# F03_P002_A2_W002_D2022-08-25-11-08-40_0079.json  F03_P002_A2_W002_D2022-08-25-11-08-40_0079.json
# F02_P001_A1_W001_D2022-08-24-11-15-55_1762.json  F02_P001_A1_W001_D2022-08-24-11-15-55_1762.json
# F04_P001_A1_W001_D2022-09-16-09-53-48_0925.json  F04_P001_A1_W001_D2022-09-16-09-53-48_0925.json
#
# [5 rows x 43 columns]

# %%
# val_df

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1995 entries, F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json to F05_P001_A3_W001_D2022-09-23-10-23-27_0464.json
# Data columns (total 43 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   neck              1995 non-null   int32
#  1   trunk             1995 non-null   int32
#  2   upperarm          1995 non-null   int32
#  3   lowerarm          1995 non-null   int32
#  4   legs              1995 non-null   int32
#  5   json_trunk_twist  1995 non-null   int32
#  6   bbox_w            1995 non-null   int32
#  7   bbox_h            1995 non-null   int32
#  8   x1                1995 non-null   int32
#  9   y1                1995 non-null   int32
#  10  x2                1995 non-null   int32
#  11  y2                1995 non-null   int32
#  12  x3                1995 non-null   int32
#  13  y3                1995 non-null   int32
#  14  x4                1995 non-null   int32
#  15  y4                1995 non-null   int32
#  16  x5                1995 non-null   int32
#  17  y5                1995 non-null   int32
#  18  x6                1995 non-null   int32
#  19  y6                1995 non-null   int32
#  20  x7                1995 non-null   int32
#  21  y7                1995 non-null   int32
#  22  x8                1995 non-null   int32
#  23  y8                1995 non-null   int32
#  24  x9                1995 non-null   int32
#  25  y9                1995 non-null   int32
#  26  x10               1995 non-null   int32
#  27  y10               1995 non-null   int32
#  28  x11               1995 non-null   int32
#  29  y11               1995 non-null   int32
#  30  x12               1995 non-null   int32
#  31  y12               1995 non-null   int32
#  32  x13               1995 non-null   int32
#  33  y13               1995 non-null   int32
#  34  x14               1995 non-null   int32
#  35  y14               1995 non-null   int32
#  36  x15               1995 non-null   int32
#  37  y15               1995 non-null   int32
#  38  x16               1995 non-null   int32
#  39  y16               1995 non-null   int32
#  40  x17               1995 non-null   int32
#  41  y17               1995 non-null   int32
#  42  json_path         1995 non-null   object
# dtypes: int32(42), object(1)
# memory usage: 358.5+ KB

# %%
test_df.shape
# Out:
# (1995, 43)

# %%
test_df.head()
# Out:
#                                                  neck  trunk  upperarm  \
# F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json     2      1         1
# F02_P001_A3_W001_D2022-08-24-11-14-35_0655.json     2      0         1
# F02_P001_A1_W001_D2022-08-24-11-15-55_0440.json     2      0         0
# F05_P001_A1_W001_D2022-09-23-10-07-01_0084.json     2      1         0
# F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json     1      0         1
#
#                                                  lowerarm  legs  \
# F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json         0     3
# F02_P001_A3_W001_D2022-08-24-11-14-35_0655.json         0     1
# F02_P001_A1_W001_D2022-08-24-11-15-55_0440.json         0     1
# F05_P001_A1_W001_D2022-09-23-10-07-01_0084.json         0     3
# F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json         0     1
#
#                                                  json_trunk_twist  bbox_w  \
# F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json                 1    3504
# F02_P001_A3_W001_D2022-08-24-11-14-35_0655.json                 0    3412
# F02_P001_A1_W001_D2022-08-24-11-15-55_0440.json                 0    4396
# F05_P001_A1_W001_D2022-09-23-10-07-01_0084.json                 0    4377
# F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json                 0    2985
#
#                                                  bbox_h   x1   y1  ...   y13  \
# F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json    8822  246  391  ...   864
# F02_P001_A3_W001_D2022-08-24-11-14-35_0655.json   10329  366  270  ...   868
# F02_P001_A1_W001_D2022-08-24-11-15-55_0440.json    7396  438  490  ...  1174
# F05_P001_A1_W001_D2022-09-23-10-07-01_0084.json    5409  444  288  ...   850
# F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json    8025  624  306  ...   760
#
#                                                  x14   y14  x15   y15  x16  \
# F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json  372  1237  462  1233  312
# F02_P001_A3_W001_D2022-08-24-11-14-35_0655.json  402  1368  582  1363  450
# F02_P001_A1_W001_D2022-08-24-11-15-55_0440.json  582  1476  288  1480  432
# F05_P001_A1_W001_D2022-09-23-10-07-01_0084.json  216   549  702   630  444
# F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json  396  1057  402  1062  408
#
#                                                   y16  x17   y17  \
# F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json  1620  600  1534
# F02_P001_A3_W001_D2022-08-24-11-14-35_0655.json  1759  600  1741
# F02_P001_A1_W001_D2022-08-24-11-15-55_0440.json  1422  420  1390
# F05_P001_A1_W001_D2022-09-23-10-07-01_0084.json   940  714   954
# F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json  1327  252  1359
#
#                                                                                        json_path
# F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json  F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json
# F02_P001_A3_W001_D2022-08-24-11-14-35_0655.json  F02_P001_A3_W001_D2022-08-24-11-14-35_0655.json
# F02_P001_A1_W001_D2022-08-24-11-15-55_0440.json  F02_P001_A1_W001_D2022-08-24-11-15-55_0440.json
# F05_P001_A1_W001_D2022-09-23-10-07-01_0084.json  F05_P001_A1_W001_D2022-09-23-10-07-01_0084.json
# F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json  F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json
#
# [5 rows x 43 columns]

# %%
# test_df

# %% [markdown]
# ### 5) X, Y Split

# %% [markdown]
# #### (1) Train

# %%
train_df.head()
# Out:
#                                                  neck  trunk  upperarm  \
# F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json     2      0         0
# F04_P001_A2_W001_D2022-09-16-10-13-12_3092.json     1      1         0
# F02_P001_A1_W001_D2022-08-24-11-15-55_1464.json     2      0         0
# F03_P001_A1_W001_D2022-09-30-13-09-04_0345.json     1      0         1
# F04_P001_A1_W001_D2022-09-16-09-53-48_0431.json     2      1         0
#
#                                                  lowerarm  legs  \
# F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json         0     1
# F04_P001_A2_W001_D2022-09-16-10-13-12_3092.json         0     1
# F02_P001_A1_W001_D2022-08-24-11-15-55_1464.json         0     1
# F03_P001_A1_W001_D2022-09-30-13-09-04_0345.json         0     1
# F04_P001_A1_W001_D2022-09-16-09-53-48_0431.json         0     0
#
#                                                  json_trunk_twist  bbox_w  \
# F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json                 0    4507
# F04_P001_A2_W001_D2022-09-16-10-13-12_3092.json                 1    4233
# F02_P001_A1_W001_D2022-08-24-11-15-55_1464.json                 0    8760
# F03_P001_A1_W001_D2022-09-30-13-09-04_0345.json                 0    2260
# F04_P001_A1_W001_D2022-09-16-09-53-48_0431.json                 0    2270
#
#                                                  bbox_h   x1   y1  ...   y13  \
# F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json    7267  504  463  ...  1111
# F04_P001_A2_W001_D2022-09-16-10-13-12_3092.json    3259  738  319  ...   459
# F02_P001_A1_W001_D2022-08-24-11-15-55_1464.json    7344  684  486  ...  1264
# F03_P001_A1_W001_D2022-09-30-13-09-04_0345.json    5505  390  252  ...   580
# F04_P001_A1_W001_D2022-09-16-09-53-48_0431.json    2606  378  229  ...   364
#
#                                                  x14   y14  x15   y15  x16  \
# F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json  756  1426  366  1435  738
# F04_P001_A2_W001_D2022-09-16-10-13-12_3092.json  576   634  342   661  546
# F02_P001_A1_W001_D2022-08-24-11-15-55_1464.json  810  1494  582  1494  822
# F03_P001_A1_W001_D2022-09-30-13-09-04_0345.json  432   738  294   751  444
# F04_P001_A1_W001_D2022-09-16-09-53-48_0431.json  468   342  282   369  414
#
#                                                   y16  x17   y17  \
# F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json  1444  408  1435
# F04_P001_A2_W001_D2022-09-16-10-13-12_3092.json   742  210   639
# F02_P001_A1_W001_D2022-08-24-11-15-55_1464.json  1503  612  1512
# F03_P001_A1_W001_D2022-09-30-13-09-04_0345.json   936  240   949
# F04_P001_A1_W001_D2022-09-16-09-53-48_0431.json   504  282   522
#
#                                                                                        json_path
# F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json  F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json
# F04_P001_A2_W001_D2022-09-16-10-13-12_3092.json  F04_P001_A2_W001_D2022-09-16-10-13-12_3092.json
# F02_P001_A1_W001_D2022-08-24-11-15-55_1464.json  F02_P001_A1_W001_D2022-08-24-11-15-55_1464.json
# F03_P001_A1_W001_D2022-09-30-13-09-04_0345.json  F03_P001_A1_W001_D2022-09-30-13-09-04_0345.json
# F04_P001_A1_W001_D2022-09-16-09-53-48_0431.json  F04_P001_A1_W001_D2022-09-16-09-53-48_0431.json
#
# [5 rows x 43 columns]

# %%
X_train_df = train_df[json_skeleton_keys]

X_train_df
# Out:
#                                                   x1   y1   x2   y2   x3   y3  \
# F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json  504  463  558  414  450  418
# F04_P001_A2_W001_D2022-09-16-10-13-12_3092.json  738  319  750  301  738  301
# F02_P001_A1_W001_D2022-08-24-11-15-55_1464.json  684  486  726  436  642  441
# F03_P001_A1_W001_D2022-09-30-13-09-04_0345.json  390  252  408  234  378  229
# F04_P001_A1_W001_D2022-09-16-09-53-48_0431.json  378  229  390  211  360  211
# ...                                              ...  ...  ...  ...  ...  ...
# F02_P001_A1_W001_D2022-08-24-11-15-55_0850.json  372  418  420  364  348  355
# F04_P001_A2_W001_D2022-09-16-10-13-12_1497.json  660  274  684  252  684  252
# F01_P001_A2_W001_D2022-08-23-10-23-00_0171.json  348  126  324  112  360  112
# F02_P001_A1_W001_D2022-08-24-11-15-55_0494.json  504  486  552  418  450  427
# F02_P001_A1_W001_D2022-08-24-11-15-55_1409.json  408  472  450  414  378  409
#
#                                                   x4   y4   x5   y5  ...  x13  \
# F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json  642  373  396  400  ...  378
# F04_P001_A2_W001_D2022-09-16-10-13-12_3092.json  708  247  666  247  ...  258
# F02_P001_A1_W001_D2022-08-24-11-15-55_1464.json  870  400  636  409  ...  576
# F03_P001_A1_W001_D2022-09-30-13-09-04_0345.json  402  229  330  220  ...  300
# F04_P001_A1_W001_D2022-09-16-09-53-48_0431.json  408  202  330  202  ...  294
# ...                                              ...  ...  ...  ...  ...  ...
# F02_P001_A1_W001_D2022-08-24-11-15-55_0850.json  546  351  378  351  ...  360
# F04_P001_A2_W001_D2022-09-16-10-13-12_1497.json  648  207  648  207  ...  276
# F01_P001_A2_W001_D2022-08-23-10-23-00_0171.json  288  126  372  117  ...  522
# F02_P001_A1_W001_D2022-08-24-11-15-55_0494.json  654  369  408  391  ...  366
# F02_P001_A1_W001_D2022-08-24-11-15-55_1409.json  582  355  396  364  ...  366
#
#                                                   y13  x14   y14  x15   y15  \
# F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json  1111  756  1426  366  1435
# F04_P001_A2_W001_D2022-09-16-10-13-12_3092.json   459  576   634  342   661
# F02_P001_A1_W001_D2022-08-24-11-15-55_1464.json  1264  810  1494  582  1494
# F03_P001_A1_W001_D2022-09-30-13-09-04_0345.json   580  432   738  294   751
# F04_P001_A1_W001_D2022-09-16-09-53-48_0431.json   364  468   342  282   369
# ...                                               ...  ...   ...  ...   ...
# F02_P001_A1_W001_D2022-08-24-11-15-55_0850.json  1125  594  1440  390  1444
# F04_P001_A2_W001_D2022-09-16-10-13-12_1497.json   486  264   733  396   760
# F01_P001_A2_W001_D2022-08-23-10-23-00_0171.json   490  324   625  540   778
# F02_P001_A1_W001_D2022-08-24-11-15-55_0494.json  1026  684  1471  420  1476
# F02_P001_A1_W001_D2022-08-24-11-15-55_1409.json  1062  588  1395  354  1354
#
#                                                  x16   y16  x17   y17
# F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json  738  1444  408  1435
# F04_P001_A2_W001_D2022-09-16-10-13-12_3092.json  546   742  210   639
# F02_P001_A1_W001_D2022-08-24-11-15-55_1464.json  822  1503  612  1512
# F03_P001_A1_W001_D2022-09-30-13-09-04_0345.json  444   936  240   949
# F04_P001_A1_W001_D2022-09-16-09-53-48_0431.json  414   504  282   522
# ...                                              ...   ...  ...   ...
# F02_P001_A1_W001_D2022-08-24-11-15-55_0850.json  564  1444  408  1417
# F04_P001_A2_W001_D2022-09-16-10-13-12_1497.json  306   981  396   990
# F01_P001_A2_W001_D2022-08-23-10-23-00_0171.json  312   697  558  1111
# F02_P001_A1_W001_D2022-08-24-11-15-55_0494.json  492  1485  420  1476
# F02_P001_A1_W001_D2022-08-24-11-15-55_1409.json  510  1336  420  1264
#
# [15963 rows x 34 columns]

# %%
args.y_default = args.y_list["neck"]
print(args.y_default)
y_neck_train_df = train_df[[args.y_default]]

y_neck_train_df
# Out:
# neck
#                                                  neck
# F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json     2
# F04_P001_A2_W001_D2022-09-16-10-13-12_3092.json     1
# F02_P001_A1_W001_D2022-08-24-11-15-55_1464.json     2
# F03_P001_A1_W001_D2022-09-30-13-09-04_0345.json     1
# F04_P001_A1_W001_D2022-09-16-09-53-48_0431.json     2
# ...                                               ...
# F02_P001_A1_W001_D2022-08-24-11-15-55_0850.json     2
# F04_P001_A2_W001_D2022-09-16-10-13-12_1497.json     2
# F01_P001_A2_W001_D2022-08-23-10-23-00_0171.json     2
# F02_P001_A1_W001_D2022-08-24-11-15-55_0494.json     2
# F02_P001_A1_W001_D2022-08-24-11-15-55_1409.json     2
#
# [15963 rows x 1 columns]

# %%
args.y_default = args.y_list["trunk"]
print(args.y_default)
y_trunk_train_df = train_df[[args.y_default]]

y_trunk_train_df
# Out:
# trunk
#                                                  trunk
# F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json      0
# F04_P001_A2_W001_D2022-09-16-10-13-12_3092.json      1
# F02_P001_A1_W001_D2022-08-24-11-15-55_1464.json      0
# F03_P001_A1_W001_D2022-09-30-13-09-04_0345.json      0
# F04_P001_A1_W001_D2022-09-16-09-53-48_0431.json      1
# ...                                                ...
# F02_P001_A1_W001_D2022-08-24-11-15-55_0850.json      0
# F04_P001_A2_W001_D2022-09-16-10-13-12_1497.json      1
# F01_P001_A2_W001_D2022-08-23-10-23-00_0171.json      1
# F02_P001_A1_W001_D2022-08-24-11-15-55_0494.json      0
# F02_P001_A1_W001_D2022-08-24-11-15-55_1409.json      0
#
# [15963 rows x 1 columns]

# %%
args.y_default = args.y_list['upperarm']
print(args.y_default)
y_upperarm_train_df = train_df[[args.y_default]]

y_upperarm_train_df
# Out:
# upperarm
#                                                  upperarm
# F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json         0
# F04_P001_A2_W001_D2022-09-16-10-13-12_3092.json         0
# F02_P001_A1_W001_D2022-08-24-11-15-55_1464.json         0
# F03_P001_A1_W001_D2022-09-30-13-09-04_0345.json         1
# F04_P001_A1_W001_D2022-09-16-09-53-48_0431.json         0
# ...                                                   ...
# F02_P001_A1_W001_D2022-08-24-11-15-55_0850.json         1
# F04_P001_A2_W001_D2022-09-16-10-13-12_1497.json         0
# F01_P001_A2_W001_D2022-08-23-10-23-00_0171.json         0
# F02_P001_A1_W001_D2022-08-24-11-15-55_0494.json         0
# F02_P001_A1_W001_D2022-08-24-11-15-55_1409.json         0
#
# [15963 rows x 1 columns]

# %%
args.y_default = args.y_list['lowerarm']
print(args.y_default)
y_lowerarm_train_df = train_df[[args.y_default]]

y_lowerarm_train_df
# Out:
# lowerarm
#                                                  lowerarm
# F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json         0
# F04_P001_A2_W001_D2022-09-16-10-13-12_3092.json         0
# F02_P001_A1_W001_D2022-08-24-11-15-55_1464.json         0
# F03_P001_A1_W001_D2022-09-30-13-09-04_0345.json         0
# F04_P001_A1_W001_D2022-09-16-09-53-48_0431.json         0
# ...                                                   ...
# F02_P001_A1_W001_D2022-08-24-11-15-55_0850.json         0
# F04_P001_A2_W001_D2022-09-16-10-13-12_1497.json         0
# F01_P001_A2_W001_D2022-08-23-10-23-00_0171.json         0
# F02_P001_A1_W001_D2022-08-24-11-15-55_0494.json         0
# F02_P001_A1_W001_D2022-08-24-11-15-55_1409.json         0
#
# [15963 rows x 1 columns]

# %%
args.y_default = args.y_list['legs']
print(args.y_default)
y_legs_train_df = train_df[[args.y_default]]

y_legs_train_df
# Out:
# legs
#                                                  legs
# F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json     1
# F04_P001_A2_W001_D2022-09-16-10-13-12_3092.json     1
# F02_P001_A1_W001_D2022-08-24-11-15-55_1464.json     1
# F03_P001_A1_W001_D2022-09-30-13-09-04_0345.json     1
# F04_P001_A1_W001_D2022-09-16-09-53-48_0431.json     0
# ...                                               ...
# F02_P001_A1_W001_D2022-08-24-11-15-55_0850.json     1
# F04_P001_A2_W001_D2022-09-16-10-13-12_1497.json     1
# F01_P001_A2_W001_D2022-08-23-10-23-00_0171.json     2
# F02_P001_A1_W001_D2022-08-24-11-15-55_0494.json     1
# F02_P001_A1_W001_D2022-08-24-11-15-55_1409.json     1
#
# [15963 rows x 1 columns]

# %%
args.y_default = args.y_list['json_trunk_twist']
print(args.y_default)
y_json_trunk_twist_train_df = train_df[[args.y_default]]

y_json_trunk_twist_train_df
# Out:
# json_trunk_twist
#                                                  json_trunk_twist
# F02_P001_A1_W001_D2022-08-24-11-15-55_1372.json                 0
# F04_P001_A2_W001_D2022-09-16-10-13-12_3092.json                 1
# F02_P001_A1_W001_D2022-08-24-11-15-55_1464.json                 0
# F03_P001_A1_W001_D2022-09-30-13-09-04_0345.json                 0
# F04_P001_A1_W001_D2022-09-16-09-53-48_0431.json                 0
# ...                                                           ...
# F02_P001_A1_W001_D2022-08-24-11-15-55_0850.json                 0
# F04_P001_A2_W001_D2022-09-16-10-13-12_1497.json                 1
# F01_P001_A2_W001_D2022-08-23-10-23-00_0171.json                 0
# F02_P001_A1_W001_D2022-08-24-11-15-55_0494.json                 0
# F02_P001_A1_W001_D2022-08-24-11-15-55_1409.json                 0
#
# [15963 rows x 1 columns]

# %% [markdown]
# #### (2) Test

# %%
test_df.head()
# Out:
#                                                  neck  trunk  upperarm  \
# F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json     2      1         1
# F02_P001_A3_W001_D2022-08-24-11-14-35_0655.json     2      0         1
# F02_P001_A1_W001_D2022-08-24-11-15-55_0440.json     2      0         0
# F05_P001_A1_W001_D2022-09-23-10-07-01_0084.json     2      1         0
# F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json     1      0         1
#
#                                                  lowerarm  legs  \
# F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json         0     3
# F02_P001_A3_W001_D2022-08-24-11-14-35_0655.json         0     1
# F02_P001_A1_W001_D2022-08-24-11-15-55_0440.json         0     1
# F05_P001_A1_W001_D2022-09-23-10-07-01_0084.json         0     3
# F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json         0     1
#
#                                                  json_trunk_twist  bbox_w  \
# F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json                 1    3504
# F02_P001_A3_W001_D2022-08-24-11-14-35_0655.json                 0    3412
# F02_P001_A1_W001_D2022-08-24-11-15-55_0440.json                 0    4396
# F05_P001_A1_W001_D2022-09-23-10-07-01_0084.json                 0    4377
# F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json                 0    2985
#
#                                                  bbox_h   x1   y1  ...   y13  \
# F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json    8822  246  391  ...   864
# F02_P001_A3_W001_D2022-08-24-11-14-35_0655.json   10329  366  270  ...   868
# F02_P001_A1_W001_D2022-08-24-11-15-55_0440.json    7396  438  490  ...  1174
# F05_P001_A1_W001_D2022-09-23-10-07-01_0084.json    5409  444  288  ...   850
# F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json    8025  624  306  ...   760
#
#                                                  x14   y14  x15   y15  x16  \
# F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json  372  1237  462  1233  312
# F02_P001_A3_W001_D2022-08-24-11-14-35_0655.json  402  1368  582  1363  450
# F02_P001_A1_W001_D2022-08-24-11-15-55_0440.json  582  1476  288  1480  432
# F05_P001_A1_W001_D2022-09-23-10-07-01_0084.json  216   549  702   630  444
# F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json  396  1057  402  1062  408
#
#                                                   y16  x17   y17  \
# F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json  1620  600  1534
# F02_P001_A3_W001_D2022-08-24-11-14-35_0655.json  1759  600  1741
# F02_P001_A1_W001_D2022-08-24-11-15-55_0440.json  1422  420  1390
# F05_P001_A1_W001_D2022-09-23-10-07-01_0084.json   940  714   954
# F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json  1327  252  1359
#
#                                                                                        json_path
# F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json  F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json
# F02_P001_A3_W001_D2022-08-24-11-14-35_0655.json  F02_P001_A3_W001_D2022-08-24-11-14-35_0655.json
# F02_P001_A1_W001_D2022-08-24-11-15-55_0440.json  F02_P001_A1_W001_D2022-08-24-11-15-55_0440.json
# F05_P001_A1_W001_D2022-09-23-10-07-01_0084.json  F05_P001_A1_W001_D2022-09-23-10-07-01_0084.json
# F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json  F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json
#
# [5 rows x 43 columns]

# %%
X_test_df = test_df[json_skeleton_keys]

X_test_df
# Out:
#                                                   x1   y1   x2   y2   x3   y3  \
# F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json  246  391  246  346  234  346
# F02_P001_A3_W001_D2022-08-24-11-14-35_0655.json  366  270  336  238  414  247
# F02_P001_A1_W001_D2022-08-24-11-15-55_0440.json  438  490  492  427  384  432
# F05_P001_A1_W001_D2022-09-23-10-07-01_0084.json  444  288  432  265  468  252
# F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json  624  306  618  279  636  283
# ...                                              ...  ...  ...  ...  ...  ...
# F03_P001_A1_W001_D2022-08-25-10-32-05_0627.json  360  292  372  270  324  279
# F05_P001_A3_W001_D2022-09-23-10-23-27_0107.json  426 -256  390 -256  396 -256
# F01_P001_A2_W001_D2022-08-23-10-23-00_0843.json  558  193  552  184  582  207
# F01_P001_A2_W001_D2022-08-23-10-12-00_0013.json  288  310  294  288  288  288
# F05_P001_A3_W001_D2022-09-23-10-23-27_0464.json  564  517  552  495  540  490
#
#                                                   x4   y4   x5   y5  ...  x13  \
# F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json  336  297  306  297  ...  540
# F02_P001_A3_W001_D2022-08-24-11-14-35_0655.json  336  265  486  270  ...  588
# F02_P001_A1_W001_D2022-08-24-11-15-55_0440.json  618  387  390  396  ...  360
# F05_P001_A1_W001_D2022-09-23-10-07-01_0084.json  438  247  540  234  ...  804
# F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json  552  279  606  288  ...  312
# ...                                              ...  ...  ...  ...  ...  ...
# F03_P001_A1_W001_D2022-08-25-10-32-05_0627.json  360  261  264  270  ...  324
# F05_P001_A3_W001_D2022-09-23-10-23-27_0107.json  390 -261  426 -189  ...  234
# F01_P001_A2_W001_D2022-08-23-10-23-00_0843.json  534  162  600  184  ...  348
# F01_P001_A2_W001_D2022-08-23-10-12-00_0013.json  330  247  336  247  ...  726
# F05_P001_A3_W001_D2022-09-23-10-23-27_0464.json  456  495  432  490  ...  378
#
#                                                   y13  x14   y14  x15   y15  \
# F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json   864  372  1237  462  1233
# F02_P001_A3_W001_D2022-08-24-11-14-35_0655.json   868  402  1368  582  1363
# F02_P001_A1_W001_D2022-08-24-11-15-55_0440.json  1174  582  1476  288  1480
# F05_P001_A1_W001_D2022-09-23-10-07-01_0084.json   850  216   549  702   630
# F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json   760  396  1057  402  1062
# ...                                               ...  ...   ...  ...   ...
# F03_P001_A1_W001_D2022-08-25-10-32-05_0627.json   760  528  1012  330  1021
# F05_P001_A3_W001_D2022-09-23-10-23-27_0107.json    58  234    13  360    54
# F01_P001_A2_W001_D2022-08-23-10-23-00_0843.json   441  390   733  420   760
# F01_P001_A2_W001_D2022-08-23-10-12-00_0013.json   567  612   873  708   877
# F05_P001_A3_W001_D2022-09-23-10-23-27_0464.json  1048  546  1359  366  1381
#
#                                                  x16   y16  x17   y17
# F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json  312  1620  600  1534
# F02_P001_A3_W001_D2022-08-24-11-14-35_0655.json  450  1759  600  1741
# F02_P001_A1_W001_D2022-08-24-11-15-55_0440.json  432  1422  420  1390
# F05_P001_A1_W001_D2022-09-23-10-07-01_0084.json  444   940  714   954
# F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json  408  1327  252  1359
# ...                                              ...   ...  ...   ...
# F03_P001_A1_W001_D2022-08-25-10-32-05_0627.json  564  1305  360  1318
# F05_P001_A3_W001_D2022-09-23-10-23-27_0107.json  156    72  216    94
# F01_P001_A2_W001_D2022-08-23-10-23-00_0843.json  426  1026  438  1030
# F01_P001_A2_W001_D2022-08-23-10-12-00_0013.json  576  1120  714  1116
# F05_P001_A3_W001_D2022-09-23-10-23-27_0464.json  474  1705  324  1678
#
# [1995 rows x 34 columns]

# %%
args.y_default = args.y_list['neck']
print(args.y_default)
y_neck_test_df = test_df[[args.y_default]]

y_neck_test_df
# Out:
# neck
#                                                  neck
# F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json     2
# F02_P001_A3_W001_D2022-08-24-11-14-35_0655.json     2
# F02_P001_A1_W001_D2022-08-24-11-15-55_0440.json     2
# F05_P001_A1_W001_D2022-09-23-10-07-01_0084.json     2
# F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json     1
# ...                                               ...
# F03_P001_A1_W001_D2022-08-25-10-32-05_0627.json     1
# F05_P001_A3_W001_D2022-09-23-10-23-27_0107.json     0
# F01_P001_A2_W001_D2022-08-23-10-23-00_0843.json     2
# F01_P001_A2_W001_D2022-08-23-10-12-00_0013.json     2
# F05_P001_A3_W001_D2022-09-23-10-23-27_0464.json     1
#
# [1995 rows x 1 columns]

# %%
args.y_default = args.y_list['trunk']
print(args.y_default)
y_trunk_test_df = test_df[[args.y_default]]

y_trunk_test_df
# Out:
# trunk
#                                                  trunk
# F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json      1
# F02_P001_A3_W001_D2022-08-24-11-14-35_0655.json      0
# F02_P001_A1_W001_D2022-08-24-11-15-55_0440.json      0
# F05_P001_A1_W001_D2022-09-23-10-07-01_0084.json      1
# F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json      0
# ...                                                ...
# F03_P001_A1_W001_D2022-08-25-10-32-05_0627.json      0
# F05_P001_A3_W001_D2022-09-23-10-23-27_0107.json      0
# F01_P001_A2_W001_D2022-08-23-10-23-00_0843.json      1
# F01_P001_A2_W001_D2022-08-23-10-12-00_0013.json      1
# F05_P001_A3_W001_D2022-09-23-10-23-27_0464.json      0
#
# [1995 rows x 1 columns]

# %%
args.y_default = args.y_list['upperarm']
print(args.y_default)
y_upperarm_test_df = test_df[[args.y_default]]

y_upperarm_test_df
# Out:
# upperarm
#                                                  upperarm
# F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json         1
# F02_P001_A3_W001_D2022-08-24-11-14-35_0655.json         1
# F02_P001_A1_W001_D2022-08-24-11-15-55_0440.json         0
# F05_P001_A1_W001_D2022-09-23-10-07-01_0084.json         0
# F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json         1
# ...                                                   ...
# F03_P001_A1_W001_D2022-08-25-10-32-05_0627.json         1
# F05_P001_A3_W001_D2022-09-23-10-23-27_0107.json         0
# F01_P001_A2_W001_D2022-08-23-10-23-00_0843.json         0
# F01_P001_A2_W001_D2022-08-23-10-12-00_0013.json         0
# F05_P001_A3_W001_D2022-09-23-10-23-27_0464.json         1
#
# [1995 rows x 1 columns]

# %%
args.y_default = args.y_list['lowerarm']
print(args.y_default)
y_lowerarm_test_df = test_df[[args.y_default]]

y_lowerarm_test_df
# Out:
# lowerarm
#                                                  lowerarm
# F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json         0
# F02_P001_A3_W001_D2022-08-24-11-14-35_0655.json         0
# F02_P001_A1_W001_D2022-08-24-11-15-55_0440.json         0
# F05_P001_A1_W001_D2022-09-23-10-07-01_0084.json         0
# F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json         0
# ...                                                   ...
# F03_P001_A1_W001_D2022-08-25-10-32-05_0627.json         0
# F05_P001_A3_W001_D2022-09-23-10-23-27_0107.json         1
# F01_P001_A2_W001_D2022-08-23-10-23-00_0843.json         0
# F01_P001_A2_W001_D2022-08-23-10-12-00_0013.json         0
# F05_P001_A3_W001_D2022-09-23-10-23-27_0464.json         0
#
# [1995 rows x 1 columns]

# %%
args.y_default = args.y_list['legs']
print(args.y_default)
y_legs_test_df = test_df[[args.y_default]]

y_legs_test_df
# Out:
# legs
#                                                  legs
# F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json     3
# F02_P001_A3_W001_D2022-08-24-11-14-35_0655.json     1
# F02_P001_A1_W001_D2022-08-24-11-15-55_0440.json     1
# F05_P001_A1_W001_D2022-09-23-10-07-01_0084.json     3
# F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json     1
# ...                                               ...
# F03_P001_A1_W001_D2022-08-25-10-32-05_0627.json     1
# F05_P001_A3_W001_D2022-09-23-10-23-27_0107.json     1
# F01_P001_A2_W001_D2022-08-23-10-23-00_0843.json     4
# F01_P001_A2_W001_D2022-08-23-10-12-00_0013.json     1
# F05_P001_A3_W001_D2022-09-23-10-23-27_0464.json     1
#
# [1995 rows x 1 columns]

# %%
args.y_default = args.y_list['json_trunk_twist']
print(args.y_default)
y_json_trunk_twist_test_df = test_df[[args.y_default]]

y_json_trunk_twist_test_df
# Out:
# json_trunk_twist
#                                                  json_trunk_twist
# F04_P002_A1_W002_D2022-09-16-10-56-38_0322.json                 1
# F02_P001_A3_W001_D2022-08-24-11-14-35_0655.json                 0
# F02_P001_A1_W001_D2022-08-24-11-15-55_0440.json                 0
# F05_P001_A1_W001_D2022-09-23-10-07-01_0084.json                 0
# F01_P001_A1_W001_D2022-08-23-10-22-00_0448.json                 0
# ...                                                           ...
# F03_P001_A1_W001_D2022-08-25-10-32-05_0627.json                 0
# F05_P001_A3_W001_D2022-09-23-10-23-27_0107.json                 1
# F01_P001_A2_W001_D2022-08-23-10-23-00_0843.json                 0
# F01_P001_A2_W001_D2022-08-23-10-12-00_0013.json                 0
# F05_P001_A3_W001_D2022-09-23-10-23-27_0464.json                 1
#
# [1995 rows x 1 columns]

# %% [markdown]
# ## 4. Model Train & Predict & Visualization

# %% [markdown]
# ### 0) Visualization Def

# %%
# confusion matrix 그리는 함수 
def plot_confusion_matrix(con_mat, labels, title='Confusion Matrix', cmap=plt.cm.get_cmap('Blues'), normalize=False):
    plt.imshow(con_mat, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    marks = np.arange(len(labels))
    nlabels = []
    for k in range(len(con_mat)):
        n = sum(con_mat[k])
        nlabel = '{0}(n={1})'.format(labels[k],n)
        nlabels.append(nlabel)
    plt.xticks(marks, labels)
    plt.yticks(marks, nlabels)

    thresh = con_mat.max() / 2.
    if normalize:
        for i, j in itertools.product(range(con_mat.shape[0]), range(con_mat.shape[1])):
            plt.text(j, i, '{0}%'.format(con_mat[i, j] * 100 / n), horizontalalignment="center", color="white" if con_mat[i, j] > thresh else "black")
    else:
        for i, j in itertools.product(range(con_mat.shape[0]), range(con_mat.shape[1])):
            plt.text(j, i, con_mat[i, j], horizontalalignment="center", color="white" if con_mat[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %% [markdown]
# ### 0) Basic + Scaling

# %% [markdown]
# #### (1) y

# %%
# "neck", "trunk", "upperarm", "lowerarm", "legs", "json_trunk_twist"
args.y_default = args.y_list['lowerarm']
print(args.y_default)

if args.y_default == "neck":
    labels = ["0", "1", "2"]
elif args.y_default == "trunk":
    labels = ["0", "1"]
elif args.y_default == "upperarm":
    labels = ["0", "1", "2", "3"]
elif args.y_default == "lowerarm":
    labels = ["0", "1", "2"]
elif args.y_default == "legs":
    labels = ["0", "1", "2", "3", "4", "5"]
elif args.y_default == "json_trunk_twist":
    labels = ["0", "1"]
# Out:
# lowerarm

# %% [markdown]
# #### (2) Scaling

# %%
scaler = args.scaler_default
X_train_scaled_df = scaler.fit_transform(X_train_df)

if not os.path.exists(saved_model_path):
    os.mkdir(saved_model_path)
    
with open(file=saved_model_path + f"scaler.pickle", mode='wb') as f:
    pickle.dump(scaler, f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 4
#       1 scaler = args.scaler_default
#       2 X_train_scaled_df = scaler.fit_transform(X_train_df)
# ----> 4 if not os.path.exists(saved_model_path):
#       5     os.mkdir(saved_model_path)
#       7 with open(file=saved_model_path + f"scaler.pickle", mode='wb') as f:
#
# NameError: name 'saved_model_path' is not defined

# %% [markdown]
# ### 1) KNN Classifier

# %%
classifier_name = "KC"
args.classifier_default = args.classifier[classifier_name]
print(args.classifier_default)

# %%
# (1) Train
classifier = args.classifier_default
classifier.fit(X_train_scaled_df, eval(f"y_{args.y_default}_train_df"))

if not os.path.exists(saved_model_path + f"{classifier_name}"):
    os.mkdir(saved_model_path + f"{classifier_name}")
    
with open(file=saved_model_path + f"{classifier_name}\\y_{args.y_default}_train_df.pickle", mode='wb') as f:
    pickle.dump(classifier, f)

# %%
# (2) Predict
with open(file=saved_model_path + f"scaler.pickle", mode='rb') as f:
    scaler = pickle.load(f)
with open(file=saved_model_path + f"{classifier_name}\\y_{args.y_default}_train_df.pickle", mode='rb') as f:
    classifier = pickle.load(f)
    
X_test_scaled_df = scaler.transform(X_test_df)
y_pred_df = classifier.predict(X_test_scaled_df)

# %%
# (3) Visualization
con_mat = confusion_matrix(eval(f"y_{args.y_default}_test_df"), y_pred_df) # Confusion Matrix
args.con_mat_logs[classifier_name] = con_mat.tolist()
con_mat

# %%
plot_confusion_matrix(con_mat, labels)

# %%
# (4) Accuracy
accuracy = accuracy_score(eval(f"y_{args.y_default}_test_df"), y_pred_df) # Accuracy
args.accuracy_logs[classifier_name] = accuracy
accuracy

# %%
# (5) Classification Report
print(classification_report(eval(f"y_{args.y_default}_test_df"), y_pred_df)) # Precision, Recall, F1 score 지표 정리
args.classification_report_logs[classifier_name] = classification_report(eval(f"y_{args.y_default}_test_df"), y_pred_df)

# %%
classifier = args.classifier_default
visualizer = ClassificationReport(classifier, classes=labels, support=True)

visualizer.fit(X_train_scaled_df, eval(f"y_{args.y_default}_train_df"))        # Fit the visualizer and the model
visualizer.score(X_test_scaled_df, eval(f"y_{args.y_default}_test_df"))        # Evaluate the model on the test data
visualizer.show()                       # Finalize and show the figure

# %% [markdown]
# #### (3) Basic + GridSearch

# %%
# (1) Train / (2) Predict
args.accuracy_log = []
for k in args.knn_neighbors_list:
    classifier = KNeighborsClassifier(n_neighbors = k)
    classifier.fit(X_train_df, eval(f"y_{args.y_default}_train_df"))
    args.accuracy_log.append(classifier.score(X_test_df, eval(f"y_{args.y_default}_test_df")))

# %%
# (3) Visualization / 4) Accuracy
plt.plot(args.knn_neighbors_list, args.accuracy_log)
plt.xlabel("k")
plt.ylabel("Test Accuracy")
plt.title("KNN Classifier Accuracy")
plt.show()

# %% [markdown]
# ### 2) Decision Tree

# %%
classifier_name = "DTC"
args.classifier_default = args.classifier[classifier_name]
print(args.classifier_default)

# %%
# (1) Train
classifier = args.classifier_default
classifier.fit(X_train_scaled_df, eval(f"y_{args.y_default}_train_df"))

if not os.path.exists(saved_model_path + f"{classifier_name}"):
    os.mkdir(saved_model_path + f"{classifier_name}")
    
with open(file=saved_model_path + f"{classifier_name}\\y_{args.y_default}_train_df.pickle", mode='wb') as f:
    pickle.dump(classifier, f)

# %%
# (2) Predict
with open(file=saved_model_path + f"scaler.pickle", mode='rb') as f:
    scaler = pickle.load(f)
with open(file=saved_model_path + f"{classifier_name}\\y_{args.y_default}_train_df.pickle", mode='rb') as f:
    classifier = pickle.load(f)
    
X_test_scaled_df = scaler.transform(X_test_df)
y_pred_df = classifier.predict(X_test_scaled_df)

# %%
# (3) Visualization
con_mat = confusion_matrix(eval(f"y_{args.y_default}_test_df"), y_pred_df) # Confusion Matrix
args.con_mat_logs[classifier_name] = con_mat.tolist()
con_mat

# %%
plot_confusion_matrix(con_mat, labels)

# %%
# (4) Accuracy
accuracy = accuracy_score(eval(f"y_{args.y_default}_test_df"), y_pred_df) # Accuracy
args.accuracy_logs[classifier_name] = accuracy
accuracy

# %%
# (5) Classification Report
print(classification_report(eval(f"y_{args.y_default}_test_df"), y_pred_df)) # Precision, Recall, F1 score 지표 정리
args.classification_report_logs[classifier_name] = classification_report(eval(f"y_{args.y_default}_test_df"), y_pred_df)

# %%
classifier = args.classifier_default
visualizer = ClassificationReport(classifier, classes=labels, support=True)

visualizer.fit(X_train_scaled_df, eval(f"y_{args.y_default}_train_df"))        # Fit the visualizer and the model
visualizer.score(X_test_scaled_df, eval(f"y_{args.y_default}_test_df"))        # Evaluate the model on the test data
visualizer.show()                       # Finalize and show the figure

# %% [markdown]
# ### 3) Random Forest

# %%
classifier_name = "RFC"
args.classifier_default = args.classifier[classifier_name]
print(args.classifier_default)

# %%
# (1) Train
classifier = args.classifier_default
classifier.fit(X_train_scaled_df, eval(f"y_{args.y_default}_train_df"))

if not os.path.exists(saved_model_path + f"{classifier_name}"):
    os.mkdir(saved_model_path + f"{classifier_name}")
    
with open(file=saved_model_path + f"{classifier_name}\\y_{args.y_default}_train_df.pickle", mode='wb') as f:
    pickle.dump(classifier, f)

# %%
# (2) Predict
with open(file=saved_model_path + f"scaler.pickle", mode='rb') as f:
    scaler = pickle.load(f)
with open(file=saved_model_path + f"{classifier_name}\\y_{args.y_default}_train_df.pickle", mode='rb') as f:
    classifier = pickle.load(f)
    
X_test_scaled_df = scaler.transform(X_test_df)
y_pred_df = classifier.predict(X_test_scaled_df)

# %%
# (3) Visualization
con_mat = confusion_matrix(eval(f"y_{args.y_default}_test_df"), y_pred_df) # Confusion Matrix
args.con_mat_logs[classifier_name] = con_mat.tolist()
con_mat

# %%
plot_confusion_matrix(con_mat, labels)

# %%
# (4) Accuracy
accuracy = accuracy_score(eval(f"y_{args.y_default}_test_df"), y_pred_df) # Accuracy
args.accuracy_logs[classifier_name] = accuracy
accuracy

# %%
# (5) Classification Report
print(classification_report(eval(f"y_{args.y_default}_test_df"), y_pred_df)) # Precision, Recall, F1 score 지표 정리
args.classification_report_logs[classifier_name] = classification_report(eval(f"y_{args.y_default}_test_df"), y_pred_df)

# %%
classifier = args.classifier_default
visualizer = ClassificationReport(classifier, classes=labels, support=True)

visualizer.fit(X_train_scaled_df, eval(f"y_{args.y_default}_train_df"))        # Fit the visualizer and the model
visualizer.score(X_test_scaled_df, eval(f"y_{args.y_default}_test_df"))        # Evaluate the model on the test data
visualizer.show()                       # Finalize and show the figure

# %%
# (6) Feature Importance
feature_scores = pd.Series(classifier.feature_importances_, index=X_train_df.columns).sort_values(ascending=False)

feature_scores

# %% [markdown]
# ### 4) SVM

# %%
classifier_name = "SVC"
args.classifier_default = args.classifier[classifier_name]
print(args.classifier_default)

# %%
# (1) Train
classifier = args.classifier_default
classifier.fit(X_train_scaled_df, eval(f"y_{args.y_default}_train_df"))

if not os.path.exists(saved_model_path + f"{classifier_name}"):
    os.mkdir(saved_model_path + f"{classifier_name}")
    
with open(file=saved_model_path + f"{classifier_name}\\y_{args.y_default}_train_df.pickle", mode='wb') as f:
    pickle.dump(classifier, f)

# %%
# (2) Predict
with open(file=saved_model_path + f"scaler.pickle", mode='rb') as f:
    scaler = pickle.load(f)
with open(file=saved_model_path + f"{classifier_name}\\y_{args.y_default}_train_df.pickle", mode='rb') as f:
    classifier = pickle.load(f)
    
X_test_scaled_df = scaler.transform(X_test_df)
y_pred_df = classifier.predict(X_test_scaled_df)

# %%
# (3) Visualization
con_mat = confusion_matrix(eval(f"y_{args.y_default}_test_df"), y_pred_df) # Confusion Matrix
args.con_mat_logs[classifier_name] = con_mat.tolist()
con_mat

# %%
plot_confusion_matrix(con_mat, labels)

# %%
# (4) Accuracy
accuracy = accuracy_score(eval(f"y_{args.y_default}_test_df"), y_pred_df) # Accuracy
args.accuracy_logs[classifier_name] = accuracy
accuracy

# %%
# (5) Classification Report
print(classification_report(eval(f"y_{args.y_default}_test_df"), y_pred_df)) # Precision, Recall, F1 score 지표 정리
args.classification_report_logs[classifier_name] = classification_report(eval(f"y_{args.y_default}_test_df"), y_pred_df)

# %%
classifier = args.classifier_default
visualizer = ClassificationReport(classifier, classes=labels, support=True)

visualizer.fit(X_train_scaled_df, eval(f"y_{args.y_default}_train_df"))        # Fit the visualizer and the model
visualizer.score(X_test_scaled_df, eval(f"y_{args.y_default}_test_df"))        # Evaluate the model on the test data
visualizer.show()                       # Finalize and show the figure

# %% [markdown]
# ### 5) Model Logs

# %% [markdown]
# #### (1) Visualization

# %%
args.accuracy_logs

# %%
args.con_mat_logs

# %%
args.classification_report_logs

# %% [markdown]
# #### (2) Save Logs

# %%
if not os.path.exists(saved_model_path + f"{classifier_name}"):
    os.mkdir(saved_model_path + f"{classifier_name}")

args.json_data = {}
with open(file=saved_model_path + f"logs_y_{args.y_default}_train_df.json", mode='w', encoding='utf-8') as f:
    args.json_data["accuracy_logs"] = args.accuracy_logs
    args.json_data["con_mat_logs"] = args.con_mat_logs
    args.json_data["classification_report_logs"] = args.classification_report_logs
    json.dump(args.json_data, f, indent="\t")

# %% [markdown]
# ### 6) Best Accuracy Model Save

# %%
args.best_classifier_name = max(args.accuracy_logs, key=args.accuracy_logs.get)
args.best_classifier_name

# %%
with open(file=saved_model_path + f"best_{args.best_classifier_name}_y_{args.y_default}_train_df.pickle", mode='wb') as f:
    pickle.dump(classifier, f)
